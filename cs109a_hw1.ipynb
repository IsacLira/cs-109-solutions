# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np

import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %%
import requests
from bs4 import BeautifulSoup 
url = 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970'
html_dict = {}

def dl_parsed_html(url):
    # Do get request of a url
    r = requests.get(url,timeout=20,verify=False)
    
    # Verify the status code, if 200, everything ok!
    if r.status_code != 200:
        return None

    #Get the hetml text from the page
    raw_html = r.text    
    soup = BeautifulSoup(raw_html,'html.parser')
    
    time.sleep(1)
    return soup

# %%
soup = dl_parsed_html(url)
# Out:
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
soup.find('title').text
# Out:
# 'Billboard Year-End Hot 100 singles of 1970 - Wikipedia'

# %%
def get_dicts(soup):
    
    tables = soup.find_all('table',{'class':'wikitable'})
    table = tables[0]
    
    lis = []
        
    for tr in table.find_all('tr')[1:]:
        sing_dict = {}
        tds_text = [td.text for td in (tr.find_all('td'))]    
        if tr.find('th'):                   
            ranking_td = tr.find('th')                    
            sing_dict['ranking'] = ranking_td.text                                    
            sing_dict['song'] = tds_text[0].split(sep = '/')
            sing_dict['band_singer'] = tds_text[1].split(sep='featuring')
        else:
            sing_dict['ranking'] = tds_text[0]
            sing_dict['song'] = tds_text[1].split(sep = '/')
            sing_dict['band_singer'] = tds_text[2].split(sep='featuring')
            
        
        atags = [td.find_all('a') for td in tr.find_all('td') if td.find('a')]           
        sing_dict['songurl'] = [atag['href'] for atag in atags[0]]        
        atitle = [atag['title'] for atag in atags[0]]        
        sing_dict['titletext'] = atitle         
    
        try: 
            href = [atag['href'] for atag in atags[1]]
        except: 
            href = None
        sing_dict['url'] = href
        lis.append(sing_dict)            
    return lis

# %%
get_dicts(soup)
# Out:
# ['Bridge over Troubled Water (song)']
#
# ['(They Long to Be) Close to You']
#
# ['American Woman']
#
# ["Raindrops Keep Fallin' on My Head"]
#
# ['War (The Temptations song)']
#
# ["Ain't No Mountain High Enough"]
#
# ["I'll Be There (The Jackson 5 song)"]
#
# ['Get Ready (The Temptations song)']
#
# ['Let It Be (song)']
#
# ['Band of Gold (Freda Payne song)']
#
# ['Mama Told Me Not to Come']
#
# ['Everything Is Beautiful']
#
# ['Make It with You']
#
# ["Hitchin' a Ride (Vanity Fare song)"]
#
# ['ABC (The Jackson 5 song)']
#
# ['The Love You Save']
#
# ["Cracklin' Rosie"]
#
# ['Candida (song)']
#
# ['Thank You (Falettinme Be Mice Elf Agin)']
#
# ['Spill the Wine']
#
# ['O-o-h Child']
#
# ['Spirit in the Sky']
#
# ['Lay Down (Candles in the Rain)']
#
# ["Ball of Confusion (That's What the World Is Today)"]
#
# ['Love on a Two-Way Street']
#
# ["Which Way You Goin' Billy? (song)"]
#
# ['All Right Now']
#
# ['I Want You Back']
#
# ['Julie, Do Ya Love Me']
#
# ['Green-Eyed Lady']
#
# ["Signed, Sealed, Delivered I'm Yours"]
#
# ['Ride Captain Ride']
#
# ['Venus (Shocking Blue song)']
#
# ['Instant Karma!']
#
# ['Patches (Chairmen of the Board song)']
#
# ["Lookin' out My Back Door"]
#
# ['Rainy Night in Georgia']
#
# ['Kenny Rogers', 'The First Edition (band)']
#
# ['Give Me Just a Little More Time']
#
# ['Love Grows (Where My Rosemary Goes)']
#
# ['The Long and Winding Road']
#
# ['Snowbird (song)']
#
# ['Reflections of My Life']
#
# ['Hey There Lonely Girl']
#
# ['The Rapper']
#
# ["He Ain't Heavy, He's My Brother"]
#
# ['Tighter, Tighter']
#
# ['Come and Get It (Badfinger song)']
#
# ['Cecilia (Simon & Garfunkel song)']
#
# ['Love Land (song)']
#
# ['Turn Back the Hands of Time (song)']
#
# ['Lola (song)']
#
# ['In the Summertime (Mungo Jerry song)']
#
# ['Indiana Wants Me']
#
# ["(I Know) I'm Losing You"]
#
# ['Easy Come, Easy Go (Bobby Sherman song)']
#
# ['Express Yourself (Charles Wright & the Watts 103rd Street Rhythm Band song)']
#
# ['Still Water (Love)']
#
# ['Make Me Smile']
#
# ['The House of the Rising Sun']
#
# ['25 or 6 to 4']
#
# ["My Baby Loves Lovin'"]
#
# ['Love or Let Me Be Lonely']
#
# ['United We Stand (song)']
#
# ["We've Only Just Begun"]
#
# ['Arizona (song)']
#
# ['Fire and Rain (song)']
#
# ['Groovy Situation']
#
# ['Evil Ways']
#
# ['No Time (The Guess Who song)']
#
# ["Didn't I (Blow Your Mind This Time)"]
#
# ['The Wonder of You']
#
# ['Up Around the Bend']
#
# ["(If You Let Me Make Love To You Then) Why Can't I Touch You?"]
#
# ["I Just Can't Help Believing"]
#
# ["It's a Shame (The Spinners song)"]
#
# ['For the Love of Him']
#
# ['Mississippi Queen']
#
# ['I Want to Take You Higher']
#
# ['The Letter (The Box Tops song)']
#
# ['Ma Belle Amie']
#
# ['The Bells (The Originals song)']
#
# ['Yellow River (song)']
#
# ["Somebody's Been Sleeping"]
#
# ['Vehicle (song)']
#
# ['Gimme Dat Ding (song)']
#
# ["Lay a Little Lovin' on Me"]
#
# ['Up the Ladder to the Roof']
#
# ["Travelin' Band"]
#
# ['Come Saturday Morning (song)']
#
# ['Psychedelic Shack (song)']
#
# ['Without Love (There Is Nothing)']
#
# ['Are You Ready? (Pacific Gas & Electric song)']
#
# ['Woodstock (song)']
#
# ["I'll Never Fall in Love Again"]
#
# ['The New Seekers']
#
# ['Walk A Mile In My Shoes']
#
# ['The Thrill Is Gone (1951 song)']
#
# ["It's Only Make Believe"]
#
# ['Call Me (Aretha Franklin song)']
# [{'band_singer': ['Simon & Garfunkel'],
#   'ranking': '1',
#   'song': ['"Bridge over Troubled Water"'],
#   'songurl': ['/wiki/Bridge_over_Troubled_Water_(song)'],
#   'titletext': ['Bridge over Troubled Water (song)'],
#   'url': ['/wiki/Simon_%26_Garfunkel']},
#  {'band_singer': ['The Carpenters'],
#   'ranking': '2',
#   'song': ['"(They Long to Be) Close to You"'],
#   'songurl': ['/wiki/(They_Long_to_Be)_Close_to_You'],
#   'titletext': ['(They Long to Be) Close to You'],
#   'url': ['/wiki/The_Carpenters']},
#  {'band_singer': ['The Guess Who'],
#   'ranking': '3',
#   'song': ['"American Woman"'],
#   'songurl': ['/wiki/American_Woman'],
#   'titletext': ['American Woman'],
#   'url': ['/wiki/The_Guess_Who']},
#  {'band_singer': ['B.J. Thomas'],
#   'ranking': '4',
#   'song': ['"Raindrops Keep Fallin\' on My Head"'],
#   'songurl': ['/wiki/Raindrops_Keep_Fallin%27_on_My_Head'],
#   'titletext': ["Raindrops Keep Fallin' on My Head"],
#   'url': ['/wiki/B.J._Thomas']},
#  {'band_singer': ['Edwin Starr'],
#   'ranking': '5',
#   'song': ['"War"'],
#   'songurl': ['/wiki/War_(The_Temptations_song)#Edwin_Starr_version'],
#   'titletext': ['War (The Temptations song)'],
#   'url': ['/wiki/Edwin_Starr']},
#  {'band_singer': ['Diana Ross'],
#   'ranking': '6',
#   'song': ['"Ain\'t No Mountain High Enough"'],
#   'songurl': ['/wiki/Ain%27t_No_Mountain_High_Enough'],
#   'titletext': ["Ain't No Mountain High Enough"],
#   'url': ['/wiki/Diana_Ross']},
#  {'band_singer': ['The Jackson 5'],
#   'ranking': '7',
#   'song': ['"I\'ll Be There"'],
#   'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)'],
#   'titletext': ["I'll Be There (The Jackson 5 song)"],
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': ['Rare Earth'],
#   'ranking': '8',
#   'song': ['"Get Ready"'],
#   'songurl': ['/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_version'],
#   'titletext': ['Get Ready (The Temptations song)'],
#   'url': ['/wiki/Rare_Earth_(band)']},
#  {'band_singer': ['The Beatles'],
#   'ranking': '9',
#   'song': ['"Let It Be"'],
#   'songurl': ['/wiki/Let_It_Be_(song)'],
#   'titletext': ['Let It Be (song)'],
#   'url': ['/wiki/The_Beatles']},
#  {'band_singer': ['Freda Payne'],
#   'ranking': '10',
#   'song': ['"Band of Gold"'],
#   'songurl': ['/wiki/Band_of_Gold_(Freda_Payne_song)'],
#   'titletext': ['Band of Gold (Freda Payne song)'],
#   'url': ['/wiki/Freda_Payne']},
#  {'band_singer': ['Three Dog Night'],
#   'ranking': '11',
#   'song': ['"Mama Told Me (Not to Come)"'],
#   'songurl': ['/wiki/Mama_Told_Me_Not_to_Come'],
#   'titletext': ['Mama Told Me Not to Come'],
#   'url': ['/wiki/Three_Dog_Night']},
#  {'band_singer': ['Ray Stevens'],
#   'ranking': '12',
#   'song': ['"Everything Is Beautiful"'],
#   'songurl': ['/wiki/Everything_Is_Beautiful'],
#   'titletext': ['Everything Is Beautiful'],
#   'url': ['/wiki/Ray_Stevens']},
#  {'band_singer': ['Bread'],
#   'ranking': '13',
#   'song': ['"Make It with You"'],
#   'songurl': ['/wiki/Make_It_with_You'],
#   'titletext': ['Make It with You'],
#   'url': ['/wiki/Bread_(band)']},
#  {'band_singer': ['Vanity Fare'],
#   'ranking': '14',
#   'song': ['"Hitchin\' a Ride"'],
#   'songurl': ['/wiki/Hitchin%27_a_Ride_(Vanity_Fare_song)'],
#   'titletext': ["Hitchin' a Ride (Vanity Fare song)"],
#   'url': ['/wiki/Vanity_Fare']},
#  {'band_singer': ['The Jackson 5'],
#   'ranking': '15',
#   'song': ['"ABC"'],
#   'songurl': ['/wiki/ABC_(The_Jackson_5_song)'],
#   'titletext': ['ABC (The Jackson 5 song)'],
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': ['The Jackson 5'],
#   'ranking': '16',
#   'song': ['"The Love You Save"'],
#   'songurl': ['/wiki/The_Love_You_Save'],
#   'titletext': ['The Love You Save'],
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': ['Neil Diamond'],
#   'ranking': '17',
#   'song': ['"Cracklin\' Rosie"'],
#   'songurl': ['/wiki/Cracklin%27_Rosie'],
#   'titletext': ["Cracklin' Rosie"],
#   'url': ['/wiki/Neil_Diamond']},
#  {'band_singer': ['Dawn'],
#   'ranking': '18',
#   'song': ['"Candida"'],
#   'songurl': ['/wiki/Candida_(song)'],
#   'titletext': ['Candida (song)'],
#   'url': ['/wiki/Tony_Orlando_and_Dawn']},
#  {'band_singer': ['Sly & the Family Stone'],
#   'ranking': '19',
#   'song': ['"Thank You (Falettinme Be Mice Elf Agin)"'],
#   'songurl': ['/wiki/Thank_You_(Falettinme_Be_Mice_Elf_Agin)'],
#   'titletext': ['Thank You (Falettinme Be Mice Elf Agin)'],
#   'url': ['/wiki/Sly_%26_the_Family_Stone']},
#  {'band_singer': ['Eric Burdon & War'],
#   'ranking': '20',
#   'song': ['"Spill the Wine"'],
#   'songurl': ['/wiki/Spill_the_Wine'],
#   'titletext': ['Spill the Wine'],
#   'url': ['/wiki/Eric_Burdon', '/wiki/War_(band)']},
#  {'band_singer': ['Five Stairsteps'],
#   'ranking': '21',
#   'song': ['"O-o-h Child"'],
#   'songurl': ['/wiki/O-o-h_Child'],
#   'titletext': ['O-o-h Child'],
#   'url': ['/wiki/Five_Stairsteps']},
#  {'band_singer': ['Norman Greenbaum'],
#   'ranking': '22',
#   'song': ['"Spirit in the Sky"'],
#   'songurl': ['/wiki/Spirit_in_the_Sky'],
#   'titletext': ['Spirit in the Sky'],
#   'url': ['/wiki/Norman_Greenbaum']},
#  {'band_singer': ['Melanie'],
#   'ranking': '23',
#   'song': ['"Lay Down (Candles in the Rain)"'],
#   'songurl': ['/wiki/Lay_Down_(Candles_in_the_Rain)'],
#   'titletext': ['Lay Down (Candles in the Rain)'],
#   'url': ['/wiki/Melanie_Safka']},
#  {'band_singer': ['The Temptations'],
#   'ranking': '24',
#   'song': ['"Ball of Confusion (That\'s What the World Is Today)"'],
#   'songurl': ['/wiki/Ball_of_Confusion_(That%27s_What_the_World_Is_Today)'],
#   'titletext': ["Ball of Confusion (That's What the World Is Today)"],
#   'url': ['/wiki/The_Temptations']},
#  {'band_singer': ['The Moments'],
#   'ranking': '25',
#   'song': ['"Love on a Two-Way Street"'],
#   'songurl': ['/wiki/Love_on_a_Two-Way_Street'],
#   'titletext': ['Love on a Two-Way Street'],
#   'url': ['/wiki/Ray,_Goodman_%26_Brown']},
#  {'band_singer': ['The Poppy Family'],
#   'ranking': '26',
#   'song': ['"Which Way You Goin\' Billy?"'],
#   'songurl': ['/wiki/Which_Way_You_Goin%27_Billy%3F_(song)'],
#   'titletext': ["Which Way You Goin' Billy? (song)"],
#   'url': ['/wiki/The_Poppy_Family']},
#  {'band_singer': ['Free'],
#   'ranking': '27',
#   'song': ['"All Right Now"'],
#   'songurl': ['/wiki/All_Right_Now'],
#   'titletext': ['All Right Now'],
#   'url': ['/wiki/Free_(band)']},
#  {'band_singer': ['The Jackson 5'],
#   'ranking': '28',
#   'song': ['"I Want You Back"'],
#   'songurl': ['/wiki/I_Want_You_Back'],
#   'titletext': ['I Want You Back'],
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': ['Bobby Sherman'],
#   'ranking': '29',
#   'song': ['"Julie, Do Ya Love Me"'],
#   'songurl': ['/wiki/Julie,_Do_Ya_Love_Me'],
#   'titletext': ['Julie, Do Ya Love Me'],
#   'url': ['/wiki/Bobby_Sherman']},
#  {'band_singer': ['Sugarloaf'],
#   'ranking': '30',
#   'song': ['"Green-Eyed Lady"'],
#   'songurl': ['/wiki/Green-Eyed_Lady'],
#   'titletext': ['Green-Eyed Lady'],
#   'url': ['/wiki/Sugarloaf_(band)']},
#  {'band_singer': ['Stevie Wonder'],
#   'ranking': '31',
#   'song': ['"Signed, Sealed, Delivered I\'m Yours"'],
#   'songurl': ['/wiki/Signed,_Sealed,_Delivered_I%27m_Yours'],
#   'titletext': ["Signed, Sealed, Delivered I'm Yours"],
#   'url': ['/wiki/Stevie_Wonder']},
#  {'band_singer': ['Blues Image'],
#   'ranking': '32',
#   'song': ['"Ride Captain Ride"'],
#   'songurl': ['/wiki/Ride_Captain_Ride'],
#   'titletext': ['Ride Captain Ride'],
#   'url': ['/wiki/Blues_Image']},
#  {'band_singer': ['Shocking Blue'],
#   'ranking': '33',
#   'song': ['"Venus"'],
#   'songurl': ['/wiki/Venus_(Shocking_Blue_song)'],
#   'titletext': ['Venus (Shocking Blue song)'],
#   'url': ['/wiki/Shocking_Blue']},
#  {'band_singer': ['John Lennon'],
#   'ranking': '34',
#   'song': ['"Instant Karma!"'],
#   'songurl': ['/wiki/Instant_Karma!'],
#   'titletext': ['Instant Karma!'],
#   'url': ['/wiki/John_Lennon']},
#  {'band_singer': ['Clarence Carter'],
#   'ranking': '35',
#   'song': ['"Patches"'],
#   'songurl': ['/wiki/Patches_(Chairmen_of_the_Board_song)'],
#   'titletext': ['Patches (Chairmen of the Board song)'],
#   'url': ['/wiki/Clarence_Carter']},
#  {'band_singer': ['Creedence Clearwater Revival'],
#   'ranking': '36',
#   'song': ['"Lookin\' out My Back Door"'],
#   'songurl': ['/wiki/Lookin%27_out_My_Back_Door'],
#   'titletext': ["Lookin' out My Back Door"],
#   'url': ['/wiki/Creedence_Clearwater_Revival']},
#  {'band_singer': ['Brook Benton'],
#   'ranking': '37',
#   'song': ['"Rainy Night in Georgia"'],
#   'songurl': ['/wiki/Rainy_Night_in_Georgia'],
#   'titletext': ['Rainy Night in Georgia'],
#   'url': ['/wiki/Brook_Benton']},
#  {'band_singer': ['Kenny Rogers & The First Edition'],
#   'ranking': '38',
#   'song': ['"Something\'s Burning"'],
#   'songurl': ['/wiki/Kenny_Rogers', '/wiki/The_First_Edition_(band)'],
#   'titletext': ['Kenny Rogers', 'The First Edition (band)'],
#   'url': None},
#  {'band_singer': ['Chairmen of the Board'],
#   'ranking': '39',
#   'song': ['"Give Me Just a Little More Time"'],
#   'songurl': ['/wiki/Give_Me_Just_a_Little_More_Time'],
#   'titletext': ['Give Me Just a Little More Time'],
#   'url': ['/wiki/Chairmen_of_the_Board']},
#  {'band_singer': ['Edison Lighthouse'],
#   'ranking': '40',
#   'song': ['"Love Grows (Where My Rosemary Goes)"'],
#   'songurl': ['/wiki/Love_Grows_(Where_My_Rosemary_Goes)'],
#   'titletext': ['Love Grows (Where My Rosemary Goes)'],
#   'url': ['/wiki/Edison_Lighthouse']},
#  {'band_singer': ['The Beatles'],
#   'ranking': '41',
#   'song': ['"The Long and Winding Road"'],
#   'songurl': ['/wiki/The_Long_and_Winding_Road'],
#   'titletext': ['The Long and Winding Road'],
#   'url': ['/wiki/The_Beatles']},
#  {'band_singer': ['Anne Murray'],
#   'ranking': '42',
#   'song': ['"Snowbird"'],
#   'songurl': ['/wiki/Snowbird_(song)'],
#   'titletext': ['Snowbird (song)'],
#   'url': ['/wiki/Anne_Murray']},
#  {'band_singer': ['Marmalade'],
#   'ranking': '43',
#   'song': ['"Reflections of My Life"'],
#   'songurl': ['/wiki/Reflections_of_My_Life'],
#   'titletext': ['Reflections of My Life'],
#   'url': ['/wiki/Marmalade_(band)']},
#  {'band_singer': ['Eddie Holman'],
#   'ranking': '44',
#   'song': ['"Hey There Lonely Girl"'],
#   'songurl': ['/wiki/Hey_There_Lonely_Girl'],
#   'titletext': ['Hey There Lonely Girl'],
#   'url': ['/wiki/Eddie_Holman']},
#  {'band_singer': ['The Jaggerz'],
#   'ranking': '45',
#   'song': ['"The Rapper"'],
#   'songurl': ['/wiki/The_Rapper'],
#   'titletext': ['The Rapper'],
#   'url': ['/wiki/The_Jaggerz']},
#  {'band_singer': ['The Hollies'],
#   'ranking': '46',
#   'song': ['"He Ain\'t Heavy, He\'s My Brother"'],
#   'songurl': ['/wiki/He_Ain%27t_Heavy,_He%27s_My_Brother'],
#   'titletext': ["He Ain't Heavy, He's My Brother"],
#   'url': ['/wiki/The_Hollies']},
#  {'band_singer': ["Alive N Kickin'"],
#   'ranking': '47',
#   'song': ['"Tighter, Tighter"'],
#   'songurl': ['/wiki/Tighter,_Tighter'],
#   'titletext': ['Tighter, Tighter'],
#   'url': ['/wiki/Alive_N_Kickin%27']},
#  {'band_singer': ['Badfinger'],
#   'ranking': '48',
#   'song': ['"Come and Get It"'],
#   'songurl': ['/wiki/Come_and_Get_It_(Badfinger_song)'],
#   'titletext': ['Come and Get It (Badfinger song)'],
#   'url': ['/wiki/Badfinger']},
#  {'band_singer': ['Simon & Garfunkel'],
#   'ranking': '49',
#   'song': ['"Cecilia"'],
#   'songurl': ['/wiki/Cecilia_(Simon_%26_Garfunkel_song)'],
#   'titletext': ['Cecilia (Simon & Garfunkel song)'],
#   'url': ['/wiki/Simon_%26_Garfunkel']},
#  {'band_singer': ['Charles Wright & the Watts 103rd Street Rhythm Band'],
#   'ranking': '50',
#   'song': ['"Love Land"'],
#   'songurl': ['/wiki/Love_Land_(song)'],
#   'titletext': ['Love Land (song)'],
#   'url': ['/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band']},
#  {'band_singer': ['Tyrone Davis'],
#   'ranking': '51',
#   'song': ['"Turn Back the Hands of Time"'],
#   'songurl': ['/wiki/Turn_Back_the_Hands_of_Time_(song)'],
#   'titletext': ['Turn Back the Hands of Time (song)'],
#   'url': ['/wiki/Tyrone_Davis']},
#  {'band_singer': ['The Kinks'],
#   'ranking': '52',
#   'song': ['"Lola"'],
#   'songurl': ['/wiki/Lola_(song)'],
#   'titletext': ['Lola (song)'],
#   'url': ['/wiki/The_Kinks']},
#  {'band_singer': ['Mungo Jerry'],
#   'ranking': '53',
#   'song': ['"In the Summertime"'],
#   'songurl': ['/wiki/In_the_Summertime_(Mungo_Jerry_song)'],
#   'titletext': ['In the Summertime (Mungo Jerry song)'],
#   'url': ['/wiki/Mungo_Jerry']},
#  {'band_singer': ['R. Dean Taylor'],
#   'ranking': '54',
#   'song': ['"Indiana Wants Me"'],
#   'songurl': ['/wiki/Indiana_Wants_Me'],
#   'titletext': ['Indiana Wants Me'],
#   'url': ['/wiki/R._Dean_Taylor']},
#  {'band_singer': ['Rare Earth'],
#   'ranking': '55',
#   'song': ['"(I Know) I\'m Losing You"'],
#   'songurl': ['/wiki/(I_Know)_I%27m_Losing_You'],
#   'titletext': ["(I Know) I'm Losing You"],
#   'url': ['/wiki/Rare_Earth_(band)']},
#  {'band_singer': ['Bobby Sherman'],
#   'ranking': '56',
#   'song': ['"Easy Come, Easy Go"'],
#   'songurl': ['/wiki/Easy_Come,_Easy_Go_(Bobby_Sherman_song)'],
#   'titletext': ['Easy Come, Easy Go (Bobby Sherman song)'],
#   'url': ['/wiki/Bobby_Sherman']},
#  {'band_singer': ['Charles Wright & the Watts 103rd Street Rhythm Band'],
#   'ranking': '57',
#   'song': ['"Express Yourself"'],
#   'songurl': ['/wiki/Express_Yourself_(Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band_song)'],
#   'titletext': ['Express Yourself (Charles Wright & the Watts 103rd Street Rhythm Band song)'],
#   'url': ['/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band']},
#  {'band_singer': ['The Four Tops'],
#   'ranking': '58',
#   'song': ['"Still Water (Love)"'],
#   'songurl': ['/wiki/Still_Water_(Love)'],
#   'titletext': ['Still Water (Love)'],
#   'url': ['/wiki/The_Four_Tops']},
#  {'band_singer': ['Chicago'],
#   'ranking': '59',
#   'song': ['"Make Me Smile"'],
#   'songurl': ['/wiki/Make_Me_Smile'],
#   'titletext': ['Make Me Smile'],
#   'url': ['/wiki/Chicago_(band)']},
#  {'band_singer': ['Frijid Pink'],
#   'ranking': '60',
#   'song': ['"The House of the Rising Sun"'],
#   'songurl': ['/wiki/The_House_of_the_Rising_Sun'],
#   'titletext': ['The House of the Rising Sun'],
#   'url': ['/wiki/Frijid_Pink']},
#  {'band_singer': ['Chicago'],
#   'ranking': '61',
#   'song': ['"25 or 6 to 4"'],
#   'songurl': ['/wiki/25_or_6_to_4'],
#   'titletext': ['25 or 6 to 4'],
#   'url': ['/wiki/Chicago_(band)']},
#  {'band_singer': ['White Plains'],
#   'ranking': '62',
#   'song': ['"My Baby Loves Lovin\'"'],
#   'songurl': ['/wiki/My_Baby_Loves_Lovin%27'],
#   'titletext': ["My Baby Loves Lovin'"],
#   'url': ['/wiki/White_Plains_(band)']},
#  {'band_singer': ['The Friends of Distinction'],
#   'ranking': '63',
#   'song': ['"Love or Let Me Be Lonely"'],
#   'songurl': ['/wiki/Love_or_Let_Me_Be_Lonely'],
#   'titletext': ['Love or Let Me Be Lonely'],
#   'url': ['/wiki/The_Friends_of_Distinction']},
#  {'band_singer': ['The Brotherhood of Man'],
#   'ranking': '64',
#   'song': ['"United We Stand"'],
#   'songurl': ['/wiki/United_We_Stand_(song)'],
#   'titletext': ['United We Stand (song)'],
#   'url': ['/wiki/The_Brotherhood_of_Man']},
#  {'band_singer': ['The Carpenters'],
#   'ranking': '65',
#   'song': ['"We\'ve Only Just Begun"'],
#   'songurl': ['/wiki/We%27ve_Only_Just_Begun'],
#   'titletext': ["We've Only Just Begun"],
#   'url': ['/wiki/The_Carpenters']},
#  {'band_singer': ['Mark Lindsay'],
#   'ranking': '66',
#   'song': ['"Arizona"'],
#   'songurl': ['/wiki/Arizona_(song)'],
#   'titletext': ['Arizona (song)'],
#   'url': ['/wiki/Mark_Lindsay']},
#  {'band_singer': ['James Taylor'],
#   'ranking': '67',
#   'song': ['"Fire and Rain"'],
#   'songurl': ['/wiki/Fire_and_Rain_(song)'],
#   'titletext': ['Fire and Rain (song)'],
#   'url': ['/wiki/James_Taylor']},
#  {'band_singer': ['Gene Chandler'],
#   'ranking': '68',
#   'song': ['"Groovy Situation"'],
#   'songurl': ['/wiki/Groovy_Situation'],
#   'titletext': ['Groovy Situation'],
#   'url': ['/wiki/Gene_Chandler']},
#  {'band_singer': ['Santana'],
#   'ranking': '69',
#   'song': ['"Evil Ways"'],
#   'songurl': ['/wiki/Evil_Ways'],
#   'titletext': ['Evil Ways'],
#   'url': ['/wiki/Santana_(band)']},
#  {'band_singer': ['The Guess Who'],
#   'ranking': '70',
#   'song': ['"No Time"'],
#   'songurl': ['/wiki/No_Time_(The_Guess_Who_song)'],
#   'titletext': ['No Time (The Guess Who song)'],
#   'url': ['/wiki/The_Guess_Who']},
#  {'band_singer': ['The Delfonics'],
#   'ranking': '71',
#   'song': ['"Didn\'t I (Blow Your Mind This Time)"'],
#   'songurl': ['/wiki/Didn%27t_I_(Blow_Your_Mind_This_Time)'],
#   'titletext': ["Didn't I (Blow Your Mind This Time)"],
#   'url': ['/wiki/The_Delfonics']},
#  {'band_singer': ['Elvis Presley'],
#   'ranking': '72',
#   'song': ['"The Wonder of You"'],
#   'songurl': ['/wiki/The_Wonder_of_You'],
#   'titletext': ['The Wonder of You'],
#   'url': ['/wiki/Elvis_Presley']},
#  {'band_singer': ['Creedence Clearwater Revival'],
#   'ranking': '73',
#   'song': ['"Up Around the Bend"'],
#   'songurl': ['/wiki/Up_Around_the_Bend'],
#   'titletext': ['Up Around the Bend'],
#   'url': ['/wiki/Creedence_Clearwater_Revival']},
#  {'band_singer': ['Ronnie Dyson'],
#   'ranking': '74',
#   'song': ['"(If You Let Me Make Love To You Then) Why Can\'t I Touch You?"'],
#   'songurl': ['/wiki/(If_You_Let_Me_Make_Love_To_You_Then)_Why_Can%27t_I_Touch_You%3F'],
#   'titletext': ["(If You Let Me Make Love To You Then) Why Can't I Touch You?"],
#   'url': ['/wiki/Ronnie_Dyson']},
#  {'band_singer': ['B.J. Thomas'],
#   'ranking': '75',
#   'song': ['"I Just Can\'t Help Believing"'],
#   'songurl': ['/wiki/I_Just_Can%27t_Help_Believing'],
#   'titletext': ["I Just Can't Help Believing"],
#   'url': ['/wiki/B.J._Thomas']},
#  {'band_singer': ['The Spinners'],
#   'ranking': '76',
#   'song': ['"It\'s a Shame"'],
#   'songurl': ['/wiki/It%27s_a_Shame_(The_Spinners_song)'],
#   'titletext': ["It's a Shame (The Spinners song)"],
#   'url': ['/wiki/The_Spinners_(American_band)']},
#  {'band_singer': ['Bobbi Martin'],
#   'ranking': '77',
#   'song': ['"For the Love of Him"'],
#   'songurl': ['/wiki/For_the_Love_of_Him'],
#   'titletext': ['For the Love of Him'],
#   'url': ['/wiki/Bobbi_Martin']},
#  {'band_singer': ['Mountain'],
#   'ranking': '78',
#   'song': ['"Mississippi Queen"'],
#   'songurl': ['/wiki/Mississippi_Queen'],
#   'titletext': ['Mississippi Queen'],
#   'url': ['/wiki/Mountain_(band)']},
#  {'band_singer': ['Ike & Tina Turner'],
#   'ranking': '79',
#   'song': ['"I Want to Take You Higher"'],
#   'songurl': ['/wiki/I_Want_to_Take_You_Higher'],
#   'titletext': ['I Want to Take You Higher'],
#   'url': ['/wiki/Ike_%26_Tina_Turner']},
#  {'band_singer': ['Joe Cocker'],
#   'ranking': '80',
#   'song': ['"The Letter"'],
#   'songurl': ['/wiki/The_Letter_(The_Box_Tops_song)'],
#   'titletext': ['The Letter (The Box Tops song)'],
#   'url': ['/wiki/Joe_Cocker']},
#  {'band_singer': ['Tee Set'],
#   'ranking': '81',
#   'song': ['"Ma Belle Amie"'],
#   'songurl': ['/wiki/Ma_Belle_Amie'],
#   'titletext': ['Ma Belle Amie'],
#   'url': ['/wiki/Tee_Set']},
#  {'band_singer': ['The Originals'],
#   'ranking': '82',
#   'song': ['"The Bells"'],
#   'songurl': ['/wiki/The_Bells_(The_Originals_song)'],
#   'titletext': ['The Bells (The Originals song)'],
#   'url': ['/wiki/The_Originals_(band)']},
#  {'band_singer': ['Christie'],
#   'ranking': '83',
#   'song': ['"Yellow River"'],
#   'songurl': ['/wiki/Yellow_River_(song)'],
#   'titletext': ['Yellow River (song)'],
#   'url': ['/wiki/Christie_(band)']},
#  {'band_singer': ['100 Proof (Aged in Soul)'],
#   'ranking': '84',
#   'song': ['"Somebody\'s Been Sleeping"'],
#   'songurl': ['/wiki/Somebody%27s_Been_Sleeping'],
#   'titletext': ["Somebody's Been Sleeping"],
#   'url': ['/wiki/100_Proof_(Aged_in_Soul)']},
#  {'band_singer': ['The Ides of March'],
#   'ranking': '85',
#   'song': ['"Vehicle"'],
#   'songurl': ['/wiki/Vehicle_(song)'],
#   'titletext': ['Vehicle (song)'],
#   'url': ['/wiki/The_Ides_of_March_(band)']},
#  {'band_singer': ['The Pipkins'],
#   'ranking': '86',
#   'song': ['"Gimme Dat Ding"'],
#   'songurl': ['/wiki/Gimme_Dat_Ding_(song)'],
#   'titletext': ['Gimme Dat Ding (song)'],
#   'url': ['/wiki/The_Pipkins']},
#  {'band_singer': ['Robin McNamara'],
#   'ranking': '87',
#   'song': ['"Lay a Little Lovin\' on Me"'],
#   'songurl': ['/wiki/Lay_a_Little_Lovin%27_on_Me'],
#   'titletext': ["Lay a Little Lovin' on Me"],
#   'url': ['/wiki/Robin_McNamara']},
#  {'band_singer': ['The Supremes'],
#   'ranking': '88',
#   'song': ['"Up the Ladder to the Roof"'],
#   'songurl': ['/wiki/Up_the_Ladder_to_the_Roof'],
#   'titletext': ['Up the Ladder to the Roof'],
#   'url': ['/wiki/The_Supremes']},
#  {'band_singer': ['Creedence Clearwater Revival'],
#   'ranking': '89',
#   'song': ['"Travelin\' Band"'],
#   'songurl': ['/wiki/Travelin%27_Band'],
#   'titletext': ["Travelin' Band"],
#   'url': ['/wiki/Creedence_Clearwater_Revival']},
#  {'band_singer': ['The Sandpipers'],
#   'ranking': '90',
#   'song': ['"Come Saturday Morning"'],
#   'songurl': ['/wiki/Come_Saturday_Morning_(song)'],
#   'titletext': ['Come Saturday Morning (song)'],
#   'url': ['/wiki/The_Sandpipers']},
#  {'band_singer': ['The Temptations'],
#   'ranking': '91',
#   'song': ['"Psychedelic Shack"'],
#   'songurl': ['/wiki/Psychedelic_Shack_(song)'],
#   'titletext': ['Psychedelic Shack (song)'],
#   'url': ['/wiki/The_Temptations']},
#  {'band_singer': ['Tom Jones'],
#   'ranking': '92',
#   'song': ['"Without Love (There Is Nothing)"'],
#   'songurl': ['/wiki/Without_Love_(There_Is_Nothing)'],
#   'titletext': ['Without Love (There Is Nothing)'],
#   'url': ['/wiki/Tom_Jones_(singer)']},
#  {'band_singer': ['Pacific Gas & Electric'],
#   'ranking': '93',
#   'song': ['"Are You Ready?"'],
#   'songurl': ['/wiki/Are_You_Ready%3F_(Pacific_Gas_%26_Electric_song)'],
#   'titletext': ['Are You Ready? (Pacific Gas & Electric song)'],
#   'url': ['/wiki/Pacific_Gas_%26_Electric_(band)']},
#  {'band_singer': ['Crosby, Stills, Nash & Young'],
#   'ranking': '94',
#   'song': ['"Woodstock"'],
#   'songurl': ['/wiki/Woodstock_(song)'],
#   'titletext': ['Woodstock (song)'],
#   'url': ['/wiki/Crosby,_Stills,_Nash_%26_Young']},
#  {'band_singer': ['Dionne Warwick'],
#   'ranking': '95',
#   'song': ['"I\'ll Never Fall in Love Again"'],
#   'songurl': ['/wiki/I%27ll_Never_Fall_in_Love_Again'],
#   'titletext': ["I'll Never Fall in Love Again"],
#   'url': ['/wiki/Dionne_Warwick']},
#  {'band_singer': ['The New Seekers'],
#   'ranking': '96',
#   'song': ['"Look What They\'ve Done to My Song Ma"'],
#   'songurl': ['/wiki/The_New_Seekers'],
#   'titletext': ['The New Seekers'],
#   'url': None},
#  {'band_singer': ['Joe South'],
#   'ranking': '97',
#   'song': ['"Walk A Mile In My Shoes"'],
#   'songurl': ['/wiki/Walk_A_Mile_In_My_Shoes'],
#   'titletext': ['Walk A Mile In My Shoes'],
#   'url': ['/wiki/Joe_South']},
#  {'band_singer': ['B.B. King'],
#   'ranking': '98',
#   'song': ['"The Thrill Is Gone"'],
#   'songurl': ['/wiki/The_Thrill_Is_Gone_(1951_song)'],
#   'titletext': ['The Thrill Is Gone (1951 song)'],
#   'url': ['/wiki/B.B._King']},
#  {'band_singer': ['Glen Campbell'],
#   'ranking': '99',
#   'song': ['"It\'s Only Make Believe"'],
#   'songurl': ['/wiki/It%27s_Only_Make_Believe'],
#   'titletext': ["It's Only Make Believe"],
#   'url': ['/wiki/Glen_Campbell']},
#  {'band_singer': ['Aretha Franklin'],
#   'ranking': '100',
#   'song': ['"Call Me"'],
#   'songurl': ['/wiki/Call_Me_(Aretha_Franklin_song)'],
#   'titletext': ['Call Me (Aretha Franklin song)'],
#   'url': ['/wiki/Aretha_Franklin']}]

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %%
years = range(1992,2014)
years_soup = {}
url = 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_'
urls = [url+str(year) for year in years]

def get_pages(urls):
    years_soups = {}
    for year,url in zip(years,urls):
        years_soups[year] = dl_parsed_html(url)                    
    return years_soups

years_soup = get_pages(urls)
# Out:
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\Lira\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""
def parse_year(the_year,year_soup):
    soup = year_soup[the_year]
    year_info = get_dicts(soup)
    return year_info

# %%
years_info = [{year:parse_year(year,years_soup)} for year in range(1992,2014)]

# %%
parse_year(1992,years_soup)
# Out:
# [{'band_singer': ['Boyz II Men'],
#   'ranking': '1',
#   'song': ['"End of the Road"'],
#   'songurl': ['/wiki/End_of_the_Road'],
#   'titletext': ['End of the Road'],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Sir Mix-a-Lot'],
#   'ranking': '2',
#   'song': ['"Baby Got Back"'],
#   'songurl': ['/wiki/Baby_Got_Back'],
#   'titletext': ['Baby Got Back'],
#   'url': ['/wiki/Sir_Mix-a-Lot']},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '3',
#   'song': ['"Jump"'],
#   'songurl': ['/wiki/Jump_(Kris_Kross_song)'],
#   'titletext': ['Jump (Kris Kross song)'],
#   'url': ['/wiki/Kris_Kross']},
#  {'band_singer': ['Vanessa Williams'],
#   'ranking': '4',
#   'song': ['"Save the Best for Last"'],
#   'songurl': ['/wiki/Save_the_Best_for_Last'],
#   'titletext': ['Save the Best for Last'],
#   'url': ['/wiki/Vanessa_L._Williams']},
#  {'band_singer': ['TLC'],
#   'ranking': '5',
#   'song': ['"Baby-Baby-Baby"'],
#   'songurl': ['/wiki/Baby-Baby-Baby'],
#   'titletext': ['Baby-Baby-Baby'],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Eric Clapton'],
#   'ranking': '6',
#   'song': ['"Tears in Heaven"'],
#   'songurl': ['/wiki/Tears_in_Heaven'],
#   'titletext': ['Tears in Heaven'],
#   'url': ['/wiki/Eric_Clapton']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '7',
#   'song': ['"My Lovin\' (You\'re Never Gonna Get It)"'],
#   'songurl': ['/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#   'titletext': ["My Lovin' (You're Never Gonna Get It)"],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Red Hot Chili Peppers'],
#   'ranking': '8',
#   'song': ['"Under the Bridge"'],
#   'songurl': ['/wiki/Under_the_Bridge'],
#   'titletext': ['Under the Bridge'],
#   'url': ['/wiki/Red_Hot_Chili_Peppers']},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '9',
#   'song': ['"All 4 Love"'],
#   'songurl': ['/wiki/All_4_Love'],
#   'titletext': ['All 4 Love'],
#   'url': ['/wiki/Color_Me_Badd']},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '10',
#   'song': ['"Just Another Day"'],
#   'songurl': ['/wiki/Just_Another_Day_(Jon_Secada_song)'],
#   'titletext': ['Just Another Day (Jon Secada song)'],
#   'url': ['/wiki/Jon_Secada']},
#  {'band_singer': ['Shanice'],
#   'ranking': '11',
#   'song': ['"I Love Your Smile"'],
#   'songurl': ['/wiki/I_Love_Your_Smile'],
#   'titletext': ['I Love Your Smile'],
#   'url': ['/wiki/Shanice']},
#  {'band_singer': ['Mr. Big'],
#   'ranking': '12',
#   'song': ['"To Be with You"'],
#   'songurl': ['/wiki/To_Be_with_You'],
#   'titletext': ['To Be with You'],
#   'url': ['/wiki/Mr._Big_(band)']},
#  {'band_singer': ['Right Said Fred'],
#   'ranking': '13',
#   'song': ['"I\'m Too Sexy"'],
#   'songurl': ['/wiki/I%27m_Too_Sexy'],
#   'titletext': ["I'm Too Sexy"],
#   'url': ['/wiki/Right_Said_Fred']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '14',
#   'song': ['"Black or White"'],
#   'songurl': ['/wiki/Black_or_White'],
#   'titletext': ['Black or White'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['Billy Ray Cyrus'],
#   'ranking': '15',
#   'song': ['"Achy Breaky Heart"'],
#   'songurl': ['/wiki/Achy_Breaky_Heart'],
#   'titletext': ['Achy Breaky Heart'],
#   'url': ['/wiki/Billy_Ray_Cyrus']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '16',
#   'song': ['"I\'ll Be There"'],
#   'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#   'titletext': ["I'll Be There (The Jackson 5 song)"],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ["Guns N' Roses"],
#   'ranking': '17',
#   'song': ['"November Rain"'],
#   'songurl': ['/wiki/November_Rain'],
#   'titletext': ['November Rain'],
#   'url': ['/wiki/Guns_N%27_Roses']},
#  {'band_singer': ['Tom Cochrane'],
#   'ranking': '18',
#   'song': ['"Life Is a Highway"'],
#   'songurl': ['/wiki/Life_Is_a_Highway'],
#   'titletext': ['Life Is a Highway'],
#   'url': ['/wiki/Tom_Cochrane']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '19',
#   'song': ['"Remember the Time"'],
#   'songurl': ['/wiki/Remember_the_Time'],
#   'titletext': ['Remember the Time'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '20',
#   'song': ['"Finally"'],
#   'songurl': ['/wiki/Finally_(CeCe_Peniston_song)'],
#   'titletext': ['Finally (CeCe Peniston song)'],
#   'url': ['/wiki/CeCe_Peniston']},
#  {'band_singer': ['Madonna'],
#   'ranking': '21',
#   'song': ['"This Used to Be My Playground"'],
#   'songurl': ['/wiki/This_Used_to_Be_My_Playground'],
#   'titletext': ['This Used to Be My Playground'],
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Patty Smyth and Don Henley'],
#   'ranking': '22',
#   'song': ['"Sometimes Love Just Ain\'t Enough"'],
#   'songurl': ['/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#   'titletext': ["Sometimes Love Just Ain't Enough"],
#   'url': ['/wiki/Patty_Smyth', '/wiki/Don_Henley']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '23',
#   'song': ['"Can\'t Let Go"'],
#   'songurl': ['/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#   'titletext': ["Can't Let Go (Mariah Carey song)"],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['House of Pain'],
#   'ranking': '24',
#   'song': ['"Jump Around"'],
#   'songurl': ['/wiki/Jump_Around'],
#   'titletext': ['Jump Around'],
#   'url': ['/wiki/House_of_Pain']},
#  {'band_singer': ['Prince and The New Power Generation'],
#   'ranking': '25',
#   'song': ['"Diamonds and Pearls"'],
#   'songurl': ['/wiki/Diamonds_and_Pearls_(song)'],
#   'titletext': ['Diamonds and Pearls (song)'],
#   'url': ['/wiki/Prince_(entertainer)', '/wiki/The_New_Power_Generation']},
#  {'band_singer': ['George Michael and Elton John'],
#   'ranking': '26',
#   'song': ['"Don\'t Let the Sun Go Down on Me"'],
#   'songurl': ['/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#   'titletext': ["Don't Let the Sun Go Down on Me"],
#   'url': ['/wiki/George_Michael', '/wiki/Elton_John']},
#  {'band_singer': ['Atlantic Starr'],
#   'ranking': '27',
#   'song': ['"Masterpiece"'],
#   'songurl': ['/wiki/Masterpiece_(Atlantic_Starr_song)'],
#   'titletext': ['Masterpiece (Atlantic Starr song)'],
#   'url': ['/wiki/Atlantic_Starr']},
#  {'band_singer': ['Celine Dion'],
#   'ranking': '28',
#   'song': ['"If You Asked Me To"'],
#   'songurl': ['/wiki/If_You_Asked_Me_To'],
#   'titletext': ['If You Asked Me To'],
#   'url': ['/wiki/Celine_Dion']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '29',
#   'song': ['"Giving Him Something He Can Feel"'],
#   'songurl': ['/wiki/Something_He_Can_Feel'],
#   'titletext': ['Something He Can Feel'],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Joe Public'],
#   'ranking': '30',
#   'song': ['"Live and Learn"'],
#   'songurl': ['/wiki/Live_and_Learn_(Joe_Public_song)'],
#   'titletext': ['Live and Learn (Joe Public song)'],
#   'url': ['/wiki/Joe_Public_(band)']},
#  {'band_singer': ['Jodeci'],
#   'ranking': '31',
#   'song': ['"Come and Talk to Me"'],
#   'songurl': ['/wiki/Come_and_Talk_to_Me'],
#   'titletext': ['Come and Talk to Me'],
#   'url': ['/wiki/Jodeci']},
#  {'band_singer': ['Nirvana'],
#   'ranking': '32',
#   'song': ['"Smells Like Teen Spirit"'],
#   'songurl': ['/wiki/Smells_Like_Teen_Spirit'],
#   'titletext': ['Smells Like Teen Spirit'],
#   'url': ['/wiki/Nirvana_(band)']},
#  {'band_singer': ['Bobby Brown'],
#   'ranking': '33',
#   'song': ['"Humpin\' Around"'],
#   'songurl': ['/wiki/Humpin%27_Around'],
#   'titletext': ["Humpin' Around"],
#   'url': ['/wiki/Bobby_Brown']},
#  {'band_singer': ['Sophie B. Hawkins'],
#   'ranking': '34',
#   'song': ['"Damn I Wish I Was Your Lover"'],
#   'songurl': ['/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#   'titletext': ['Damn I Wish I Was Your Lover'],
#   'url': ['/wiki/Sophie_B._Hawkins']},
#  {'band_singer': ['Tevin Campbell'],
#   'ranking': '35',
#   'song': ['"Tell Me What You Want Me to Do"'],
#   'songurl': ['/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#   'titletext': ['Tell Me What You Want Me to Do'],
#   'url': ['/wiki/Tevin_Campbell']},
#  {'band_singer': ['TLC'],
#   'ranking': '36',
#   'song': ['"Ain\'t 2 Proud 2 Beg"'],
#   'songurl': ['/wiki/Ain%27t_2_Proud_2_Beg'],
#   'titletext': ["Ain't 2 Proud 2 Beg"],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '37',
#   'song': ['"It\'s So Hard to Say Goodbye to Yesterday"'],
#   'songurl': ['/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#   'titletext': ["It's So Hard to Say Goodbye to Yesterday"],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Technotronic ', ' Ya Kid K'],
#   'ranking': '38',
#   'song': ['"Move This"'],
#   'songurl': ['/wiki/Move_This'],
#   'titletext': ['Move This'],
#   'url': ['/wiki/Technotronic', '/wiki/Ya_Kid_K']},
#  {'band_singer': ['Queen'],
#   'ranking': '39',
#   'song': ['"Bohemian Rhapsody"'],
#   'songurl': ['/wiki/Bohemian_Rhapsody'],
#   'titletext': ['Bohemian Rhapsody'],
#   'url': ['/wiki/Queen_(band)']},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '40',
#   'song': ['"Tennessee"'],
#   'songurl': ['/wiki/Tennessee_(Arrested_Development_song)'],
#   'titletext': ['Tennessee (Arrested Development song)'],
#   'url': ['/wiki/Arrested_Development_(group)']},
#  {'band_singer': ['Luther Vandross and Janet Jackson'],
#   'ranking': '41',
#   'song': ['"The Best Things in Life Are Free"'],
#   'songurl': ['/wiki/The_Best_Things_in_Life_Are_Free'],
#   'titletext': ['The Best Things in Life Are Free'],
#   'url': ['/wiki/Luther_Vandross', '/wiki/Janet_Jackson']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '42',
#   'song': ['"Make It Happen"'],
#   'songurl': ['/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#   'titletext': ['Make It Happen (Mariah Carey song)'],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['Elton John'],
#   'ranking': '43',
#   'song': ['"The One"'],
#   'songurl': ['/wiki/The_One_(Elton_John_song)'],
#   'titletext': ['The One (Elton John song)'],
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '44',
#   'song': ['"Set Adrift on Memory Bliss"'],
#   'songurl': ['/wiki/Set_Adrift_on_Memory_Bliss'],
#   'titletext': ['Set Adrift on Memory Bliss'],
#   'url': ['/wiki/P.M._Dawn']},
#  {'band_singer': ['Shakespears Sister'],
#   'ranking': '45',
#   'song': ['"Stay"'],
#   'songurl': ['/wiki/Stay_(Shakespears_Sister_song)'],
#   'titletext': ['Stay (Shakespears Sister song)'],
#   'url': ['/wiki/Shakespears_Sister']},
#  {'band_singer': ['Hammer'],
#   'ranking': '46',
#   'song': ['"2 Legit 2 Quit"'],
#   'songurl': ['/wiki/Too_Legit_to_Quit_(song)'],
#   'titletext': ['Too Legit to Quit (song)'],
#   'url': ['/wiki/MC_Hammer']},
#  {'band_singer': ['KWS'],
#   'ranking': '47',
#   'song': ['"Please Don\'t Go"'],
#   'songurl': ['/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#   'titletext': ["Please Don't Go (KC and the Sunshine Band song)"],
#   'url': ['/wiki/KWS_(band)']},
#  {'band_singer': ['Mint Condition'],
#   'ranking': '48',
#   'song': ['"Breakin\' My Heart (Pretty Brown Eyes)"'],
#   'songurl': ['/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#   'titletext': ["Breakin' My Heart (Pretty Brown Eyes)"],
#   'url': ['/wiki/Mint_Condition']},
#  {'band_singer': ['The Cover Girls'],
#   'ranking': '49',
#   'song': ['"Wishing on a Star"'],
#   'songurl': ['/wiki/Wishing_on_a_Star'],
#   'titletext': ['Wishing on a Star'],
#   'url': ['/wiki/The_Cover_Girls']},
#  {'band_singer': ['Hi-Five'],
#   'ranking': '50',
#   'song': ['"She\'s Playing Hard to Get"'],
#   'songurl': ['/wiki/Hi-Five'],
#   'titletext': ['Hi-Five'],
#   'url': None},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '51',
#   'song': ['"I\'d Die Without You"'],
#   'songurl': ['/wiki/I%27d_Die_Without_You'],
#   'titletext': ["I'd Die Without You"],
#   'url': ['/wiki/P.M._Dawn']},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '52',
#   'song': ['"Good for Me"'],
#   'songurl': ['/wiki/Good_for_Me_(song)'],
#   'titletext': ['Good for Me (song)'],
#   'url': ['/wiki/Amy_Grant']},
#  {'band_singer': ['Toad the Wet Sprocket'],
#   'ranking': '53',
#   'song': ['"All I Want"'],
#   'songurl': ['/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#   'titletext': ['All I Want (Toad the Wet Sprocket song)'],
#   'url': ['/wiki/Toad_the_Wet_Sprocket']},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '54',
#   'song': ['"When a Man Loves a Woman"'],
#   'songurl': ['/wiki/When_a_Man_Loves_a_Woman_(song)'],
#   'titletext': ['When a Man Loves a Woman (song)'],
#   'url': ['/wiki/Michael_Bolton']},
#  {'band_singer': ['Genesis'],
#   'ranking': '55',
#   'song': ['"I Can\'t Dance"'],
#   'songurl': ['/wiki/I_Can%27t_Dance'],
#   'titletext': ["I Can't Dance"],
#   'url': ['/wiki/Genesis_(band)']},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '56',
#   'song': ['"Hazard"'],
#   'songurl': ['/wiki/Hazard_(song)'],
#   'titletext': ['Hazard (song)'],
#   'url': ['/wiki/Richard_Marx']},
#  {'band_singer': ['U2'],
#   'ranking': '57',
#   'song': ['"Mysterious Ways"'],
#   'songurl': ['/wiki/Mysterious_Ways_(song)'],
#   'titletext': ['Mysterious Ways (song)'],
#   'url': ['/wiki/U2']},
#  {'band_singer': ['George Michael'],
#   'ranking': '58',
#   'song': ['"Too Funky"'],
#   'songurl': ['/wiki/Too_Funky'],
#   'titletext': ['Too Funky'],
#   'url': ['/wiki/George_Michael']},
#  {'band_singer': ['The Heights'],
#   'ranking': '59',
#   'song': ['"How Do You Talk to an Angel"'],
#   'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#   'titletext': ['How Do You Talk to an Angel'],
#   'url': ['/wiki/The_Heights_(TV_series)']},
#  {'band_singer': ['U2'],
#   'ranking': '60',
#   'song': ['"One"'],
#   'songurl': ['/wiki/One_(U2_song)'],
#   'titletext': ['One (U2 song)'],
#   'url': ['/wiki/U2']},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '61',
#   'song': ['"Keep on Walkin\'"'],
#   'songurl': ['/wiki/Keep_on_Walkin%27_(song)'],
#   'titletext': ["Keep on Walkin' (song)"],
#   'url': ['/wiki/CeCe_Peniston']},
#  {'band_singer': ['Genesis'],
#   'ranking': '62',
#   'song': ['"Hold on My Heart"'],
#   'songurl': ['/wiki/Hold_on_My_Heart'],
#   'titletext': ['Hold on My Heart'],
#   'url': ['/wiki/Genesis_(band)']},
#  {'band_singer': ['Karyn White'],
#   'ranking': '63',
#   'song': ['"The Way I Feel About You"'],
#   'songurl': ['/wiki/Karyn_White'],
#   'titletext': ['Karyn White'],
#   'url': None},
#  {'band_singer': ['Celine Dion and Peabo Bryson'],
#   'ranking': '64',
#   'song': ['"Beauty and the Beast"'],
#   'songurl': ['/wiki/Beauty_and_the_Beast_(Disney_song)'],
#   'titletext': ['Beauty and the Beast (Disney song)'],
#   'url': ['/wiki/Celine_Dion', '/wiki/Peabo_Bryson']},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '65',
#   'song': ['"Warm It Up"'],
#   'songurl': ['/wiki/Warm_It_Up'],
#   'titletext': ['Warm It Up'],
#   'url': ['/wiki/Kris_Kross']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '66',
#   'song': ['"In the Closet"'],
#   'songurl': ['/wiki/In_the_Closet'],
#   'titletext': ['In the Closet'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '67',
#   'song': ['"People Everyday"'],
#   'songurl': ['/wiki/People_Everyday'],
#   'titletext': ['People Everyday'],
#   'url': ['/wiki/Arrested_Development_(group)']},
#  {'band_singer': ['Genesis'],
#   'ranking': '68',
#   'song': ['"No Son of Mine"'],
#   'songurl': ['/wiki/No_Son_of_Mine'],
#   'titletext': ['No Son of Mine'],
#   'url': ['/wiki/Genesis_(band)']},
#  {'band_singer': ['Marky Mark and the Funky Bunch'],
#   'ranking': '69',
#   'song': ['"Wildside"'],
#   'songurl': ['/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#   'titletext': ['Wildside (Marky Mark and the Funky Bunch song)'],
#   'url': ['/wiki/Marky_Mark_and_the_Funky_Bunch']},
#  {'band_singer': ['Bryan Adams'],
#   'ranking': '70',
#   'song': ['"Do I Have to Say the Words?"'],
#   'songurl': ['/wiki/Do_I_Have_to_Say_the_Words%3F'],
#   'titletext': ['Do I Have to Say the Words?'],
#   'url': ['/wiki/Bryan_Adams']},
#  {'band_singer': ['The Cure'],
#   'ranking': '71',
#   'song': ['"Friday I\'m in Love"'],
#   'songurl': ['/wiki/Friday_I%27m_in_Love'],
#   'titletext': ["Friday I'm in Love"],
#   'url': ['/wiki/The_Cure']},
#  {'band_singer': ['Ugly Kid Joe'],
#   'ranking': '72',
#   'song': ['"Everything About You"'],
#   'songurl': ['/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#   'titletext': ['Everything About You (Ugly Kid Joe song)'],
#   'url': ['/wiki/Ugly_Kid_Joe']},
#  {'band_singer': ['Paula Abdul'],
#   'ranking': '73',
#   'song': ['"Blowing Kisses in the Wind"'],
#   'songurl': ['/wiki/Blowing_Kisses_in_the_Wind'],
#   'titletext': ['Blowing Kisses in the Wind'],
#   'url': ['/wiki/Paula_Abdul']},
#  {'band_singer': ['Bryan Adams'],
#   'ranking': '74',
#   'song': ['"Thought I\'d Died and Gone to Heaven"'],
#   'songurl': ['/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#   'titletext': ["Thought I'd Died and Gone to Heaven"],
#   'url': ['/wiki/Bryan_Adams']},
#  {'band_singer': ['Snap!'],
#   'ranking': '75',
#   'song': ['"Rhythm Is a Dancer"'],
#   'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#   'titletext': ['Rhythm Is a Dancer'],
#   'url': ['/wiki/Snap!']},
#  {'band_singer': ['Hammer'],
#   'ranking': '76',
#   'song': ['"Addams Groove"'],
#   'songurl': ['/wiki/Addams_Groove'],
#   'titletext': ['Addams Groove'],
#   'url': ['/wiki/MC_Hammer']},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '77',
#   'song': ['"Missing You Now"'],
#   'songurl': ['/wiki/Missing_You_Now'],
#   'titletext': ['Missing You Now'],
#   'url': ['/wiki/Michael_Bolton']},
#  {'band_singer': ['N2Deep'],
#   'ranking': '78',
#   'song': ['"Back to the Hotel"'],
#   'songurl': ['/wiki/N2Deep'],
#   'titletext': ['N2Deep'],
#   'url': None},
#  {'band_singer': ['Kathy Troccoli'],
#   'ranking': '79',
#   'song': ['"Everything Changes"'],
#   'songurl': ['/wiki/Kathy_Troccoli'],
#   'titletext': ['Kathy Troccoli'],
#   'url': None},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '80',
#   'song': ['"Have You Ever Needed Someone So Bad"'],
#   'songurl': ['/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#   'titletext': ['Have You Ever Needed Someone So Bad'],
#   'url': ['/wiki/Def_Leppard']},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '81',
#   'song': ['"Take This Heart"'],
#   'songurl': ['/wiki/Take_This_Heart'],
#   'titletext': ['Take This Heart'],
#   'url': ['/wiki/Richard_Marx']},
#  {'band_singer': ['FireHouse'],
#   'ranking': '82',
#   'song': ['"When I Look Into Your Eyes"'],
#   'songurl': ['/wiki/When_I_Look_Into_Your_Eyes'],
#   'titletext': ['When I Look Into Your Eyes'],
#   'url': ['/wiki/FireHouse_(band)']},
#  {'band_singer': ['Jade'],
#   'ranking': '83',
#   'song': ['"I Wanna Love You"'],
#   'songurl': ['/wiki/I_Wanna_Love_You_(Jade_song)'],
#   'titletext': ['I Wanna Love You (Jade song)'],
#   'url': ['/wiki/Jade_(American_band)']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '84',
#   'song': ['"Uhh Ahh"'],
#   'songurl': ['/wiki/Uhh_Ahh'],
#   'titletext': ['Uhh Ahh'],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Mary J. Blige'],
#   'ranking': '85',
#   'song': ['"Real Love"'],
#   'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#   'titletext': ['Real Love (Mary J. Blige song)'],
#   'url': ['/wiki/Mary_J._Blige']},
#  {'band_singer': ['The KLF'],
#   'ranking': '86',
#   'song': ['"Justified and Ancient"'],
#   'songurl': ['/wiki/Justified_and_Ancient'],
#   'titletext': ['Justified and Ancient'],
#   'url': ['/wiki/The_KLF']},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '87',
#   'song': ['"Slow Motion"'],
#   'songurl': ['/wiki/Color_Me_Badd'],
#   'titletext': ['Color Me Badd'],
#   'url': None},
#  {'band_singer': ['TLC'],
#   'ranking': '88',
#   'song': ['"What About Your Friends"'],
#   'songurl': ['/wiki/What_About_Your_Friends'],
#   'titletext': ['What About Your Friends'],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '89',
#   'song': ['"Thinkin\' Back"'],
#   'songurl': ['/wiki/Color_Me_Badd'],
#   'titletext': ['Color Me Badd'],
#   'url': None},
#  {'band_singer': ['Charles & Eddie'],
#   'ranking': '90',
#   'song': ['"Would I Lie to You?"'],
#   'songurl': ['/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#   'titletext': ['Would I Lie to You? (Charles & Eddie song)'],
#   'url': ['/wiki/Charles_%26_Eddie']},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '91',
#   'song': ['"That\'s What Love Is For"'],
#   'songurl': ['/wiki/That%27s_What_Love_Is_For'],
#   'titletext': ["That's What Love Is For"],
#   'url': ['/wiki/Amy_Grant']},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '92',
#   'song': ['"Keep Coming Back"'],
#   'songurl': ['/wiki/Keep_Coming_Back_(song)'],
#   'titletext': ['Keep Coming Back (song)'],
#   'url': ['/wiki/Richard_Marx']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '93',
#   'song': ['"Free Your Mind"'],
#   'songurl': ['/wiki/Free_Your_Mind_(song)'],
#   'titletext': ['Free Your Mind (song)'],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Keith Sweat'],
#   'ranking': '94',
#   'song': ['"Keep It Comin\'"'],
#   'songurl': ['/wiki/Keep_It_Comin%27_(song)'],
#   'titletext': ["Keep It Comin' (song)"],
#   'url': ['/wiki/Keith_Sweat']},
#  {'band_singer': ['Mr. Big'],
#   'ranking': '95',
#   'song': ['"Just Take My Heart"'],
#   'songurl': ['/wiki/Mr._Big_(band)'],
#   'titletext': ['Mr. Big (band)'],
#   'url': None},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '96',
#   'song': ['"I Will Remember You"'],
#   'songurl': ['/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#   'titletext': ['I Will Remember You (Amy Grant song)'],
#   'url': ['/wiki/Amy_Grant']},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '97',
#   'song': ['"We Got a Love Thang"'],
#   'songurl': ['/wiki/We_Got_a_Love_Thang'],
#   'titletext': ['We Got a Love Thang'],
#   'url': ['/wiki/CeCe_Peniston']},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '98',
#   'song': ['"Let\'s Get Rocked"'],
#   'songurl': ['/wiki/Let%27s_Get_Rocked'],
#   'titletext': ["Let's Get Rocked"],
#   'url': ['/wiki/Def_Leppard']},
#  {'band_singer': ['Das EFX'],
#   'ranking': '99',
#   'song': ['"They Want EFX"'],
#   'songurl': ['/wiki/They_Want_EFX'],
#   'titletext': ['They Want EFX'],
#   'url': ['/wiki/Das_EFX']},
#  {'band_singer': ['Bonnie Raitt'],
#   'ranking': '100',
#   'song': ['"I Can\'t Make You Love Me"'],
#   'songurl': ['/wiki/I_Can%27t_Make_You_Love_Me'],
#   'titletext': ["I Can't Make You Love Me"],
#   'url': ['/wiki/Bonnie_Raitt']}]

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json
import pickle
#years_info[0]

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open('years_info.pkl','wb') as f:
    pickle.dump(years_info,f,pickle.HIGHEST_PROTOCOL)

# %%
# Read the json file to obtain the dicts
with open("years_info.pkl",'rb') as f:
    r = pickle.load(f)

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %%
years_lis = [years_info[i] for i in range(2014-1992)]
dicts_lis = [l[year] for year,l in zip(range(1992,2014),years_lis)]

# %%
dicts
# Out:
# [{'band_singer': ['Boyz II Men'],
#   'ranking': '1',
#   'song': ['"End of the Road"'],
#   'songurl': ['/wiki/End_of_the_Road'],
#   'titletext': ['End of the Road'],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Sir Mix-a-Lot'],
#   'ranking': '2',
#   'song': ['"Baby Got Back"'],
#   'songurl': ['/wiki/Baby_Got_Back'],
#   'titletext': ['Baby Got Back'],
#   'url': ['/wiki/Sir_Mix-a-Lot']},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '3',
#   'song': ['"Jump"'],
#   'songurl': ['/wiki/Jump_(Kris_Kross_song)'],
#   'titletext': ['Jump (Kris Kross song)'],
#   'url': ['/wiki/Kris_Kross']},
#  {'band_singer': ['Vanessa Williams'],
#   'ranking': '4',
#   'song': ['"Save the Best for Last"'],
#   'songurl': ['/wiki/Save_the_Best_for_Last'],
#   'titletext': ['Save the Best for Last'],
#   'url': ['/wiki/Vanessa_L._Williams']},
#  {'band_singer': ['TLC'],
#   'ranking': '5',
#   'song': ['"Baby-Baby-Baby"'],
#   'songurl': ['/wiki/Baby-Baby-Baby'],
#   'titletext': ['Baby-Baby-Baby'],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Eric Clapton'],
#   'ranking': '6',
#   'song': ['"Tears in Heaven"'],
#   'songurl': ['/wiki/Tears_in_Heaven'],
#   'titletext': ['Tears in Heaven'],
#   'url': ['/wiki/Eric_Clapton']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '7',
#   'song': ['"My Lovin\' (You\'re Never Gonna Get It)"'],
#   'songurl': ['/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#   'titletext': ["My Lovin' (You're Never Gonna Get It)"],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Red Hot Chili Peppers'],
#   'ranking': '8',
#   'song': ['"Under the Bridge"'],
#   'songurl': ['/wiki/Under_the_Bridge'],
#   'titletext': ['Under the Bridge'],
#   'url': ['/wiki/Red_Hot_Chili_Peppers']},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '9',
#   'song': ['"All 4 Love"'],
#   'songurl': ['/wiki/All_4_Love'],
#   'titletext': ['All 4 Love'],
#   'url': ['/wiki/Color_Me_Badd']},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '10',
#   'song': ['"Just Another Day"'],
#   'songurl': ['/wiki/Just_Another_Day_(Jon_Secada_song)'],
#   'titletext': ['Just Another Day (Jon Secada song)'],
#   'url': ['/wiki/Jon_Secada']},
#  {'band_singer': ['Shanice'],
#   'ranking': '11',
#   'song': ['"I Love Your Smile"'],
#   'songurl': ['/wiki/I_Love_Your_Smile'],
#   'titletext': ['I Love Your Smile'],
#   'url': ['/wiki/Shanice']},
#  {'band_singer': ['Mr. Big'],
#   'ranking': '12',
#   'song': ['"To Be with You"'],
#   'songurl': ['/wiki/To_Be_with_You'],
#   'titletext': ['To Be with You'],
#   'url': ['/wiki/Mr._Big_(band)']},
#  {'band_singer': ['Right Said Fred'],
#   'ranking': '13',
#   'song': ['"I\'m Too Sexy"'],
#   'songurl': ['/wiki/I%27m_Too_Sexy'],
#   'titletext': ["I'm Too Sexy"],
#   'url': ['/wiki/Right_Said_Fred']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '14',
#   'song': ['"Black or White"'],
#   'songurl': ['/wiki/Black_or_White'],
#   'titletext': ['Black or White'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['Billy Ray Cyrus'],
#   'ranking': '15',
#   'song': ['"Achy Breaky Heart"'],
#   'songurl': ['/wiki/Achy_Breaky_Heart'],
#   'titletext': ['Achy Breaky Heart'],
#   'url': ['/wiki/Billy_Ray_Cyrus']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '16',
#   'song': ['"I\'ll Be There"'],
#   'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#   'titletext': ["I'll Be There (The Jackson 5 song)"],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ["Guns N' Roses"],
#   'ranking': '17',
#   'song': ['"November Rain"'],
#   'songurl': ['/wiki/November_Rain'],
#   'titletext': ['November Rain'],
#   'url': ['/wiki/Guns_N%27_Roses']},
#  {'band_singer': ['Tom Cochrane'],
#   'ranking': '18',
#   'song': ['"Life Is a Highway"'],
#   'songurl': ['/wiki/Life_Is_a_Highway'],
#   'titletext': ['Life Is a Highway'],
#   'url': ['/wiki/Tom_Cochrane']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '19',
#   'song': ['"Remember the Time"'],
#   'songurl': ['/wiki/Remember_the_Time'],
#   'titletext': ['Remember the Time'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '20',
#   'song': ['"Finally"'],
#   'songurl': ['/wiki/Finally_(CeCe_Peniston_song)'],
#   'titletext': ['Finally (CeCe Peniston song)'],
#   'url': ['/wiki/CeCe_Peniston']},
#  {'band_singer': ['Madonna'],
#   'ranking': '21',
#   'song': ['"This Used to Be My Playground"'],
#   'songurl': ['/wiki/This_Used_to_Be_My_Playground'],
#   'titletext': ['This Used to Be My Playground'],
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Patty Smyth and Don Henley'],
#   'ranking': '22',
#   'song': ['"Sometimes Love Just Ain\'t Enough"'],
#   'songurl': ['/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#   'titletext': ["Sometimes Love Just Ain't Enough"],
#   'url': ['/wiki/Patty_Smyth', '/wiki/Don_Henley']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '23',
#   'song': ['"Can\'t Let Go"'],
#   'songurl': ['/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#   'titletext': ["Can't Let Go (Mariah Carey song)"],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['House of Pain'],
#   'ranking': '24',
#   'song': ['"Jump Around"'],
#   'songurl': ['/wiki/Jump_Around'],
#   'titletext': ['Jump Around'],
#   'url': ['/wiki/House_of_Pain']},
#  {'band_singer': ['Prince and The New Power Generation'],
#   'ranking': '25',
#   'song': ['"Diamonds and Pearls"'],
#   'songurl': ['/wiki/Diamonds_and_Pearls_(song)'],
#   'titletext': ['Diamonds and Pearls (song)'],
#   'url': ['/wiki/Prince_(entertainer)', '/wiki/The_New_Power_Generation']},
#  {'band_singer': ['George Michael and Elton John'],
#   'ranking': '26',
#   'song': ['"Don\'t Let the Sun Go Down on Me"'],
#   'songurl': ['/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#   'titletext': ["Don't Let the Sun Go Down on Me"],
#   'url': ['/wiki/George_Michael', '/wiki/Elton_John']},
#  {'band_singer': ['Atlantic Starr'],
#   'ranking': '27',
#   'song': ['"Masterpiece"'],
#   'songurl': ['/wiki/Masterpiece_(Atlantic_Starr_song)'],
#   'titletext': ['Masterpiece (Atlantic Starr song)'],
#   'url': ['/wiki/Atlantic_Starr']},
#  {'band_singer': ['Celine Dion'],
#   'ranking': '28',
#   'song': ['"If You Asked Me To"'],
#   'songurl': ['/wiki/If_You_Asked_Me_To'],
#   'titletext': ['If You Asked Me To'],
#   'url': ['/wiki/Celine_Dion']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '29',
#   'song': ['"Giving Him Something He Can Feel"'],
#   'songurl': ['/wiki/Something_He_Can_Feel'],
#   'titletext': ['Something He Can Feel'],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Joe Public'],
#   'ranking': '30',
#   'song': ['"Live and Learn"'],
#   'songurl': ['/wiki/Live_and_Learn_(Joe_Public_song)'],
#   'titletext': ['Live and Learn (Joe Public song)'],
#   'url': ['/wiki/Joe_Public_(band)']},
#  {'band_singer': ['Jodeci'],
#   'ranking': '31',
#   'song': ['"Come and Talk to Me"'],
#   'songurl': ['/wiki/Come_and_Talk_to_Me'],
#   'titletext': ['Come and Talk to Me'],
#   'url': ['/wiki/Jodeci']},
#  {'band_singer': ['Nirvana'],
#   'ranking': '32',
#   'song': ['"Smells Like Teen Spirit"'],
#   'songurl': ['/wiki/Smells_Like_Teen_Spirit'],
#   'titletext': ['Smells Like Teen Spirit'],
#   'url': ['/wiki/Nirvana_(band)']},
#  {'band_singer': ['Bobby Brown'],
#   'ranking': '33',
#   'song': ['"Humpin\' Around"'],
#   'songurl': ['/wiki/Humpin%27_Around'],
#   'titletext': ["Humpin' Around"],
#   'url': ['/wiki/Bobby_Brown']},
#  {'band_singer': ['Sophie B. Hawkins'],
#   'ranking': '34',
#   'song': ['"Damn I Wish I Was Your Lover"'],
#   'songurl': ['/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#   'titletext': ['Damn I Wish I Was Your Lover'],
#   'url': ['/wiki/Sophie_B._Hawkins']},
#  {'band_singer': ['Tevin Campbell'],
#   'ranking': '35',
#   'song': ['"Tell Me What You Want Me to Do"'],
#   'songurl': ['/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#   'titletext': ['Tell Me What You Want Me to Do'],
#   'url': ['/wiki/Tevin_Campbell']},
#  {'band_singer': ['TLC'],
#   'ranking': '36',
#   'song': ['"Ain\'t 2 Proud 2 Beg"'],
#   'songurl': ['/wiki/Ain%27t_2_Proud_2_Beg'],
#   'titletext': ["Ain't 2 Proud 2 Beg"],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '37',
#   'song': ['"It\'s So Hard to Say Goodbye to Yesterday"'],
#   'songurl': ['/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#   'titletext': ["It's So Hard to Say Goodbye to Yesterday"],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Technotronic ', ' Ya Kid K'],
#   'ranking': '38',
#   'song': ['"Move This"'],
#   'songurl': ['/wiki/Move_This'],
#   'titletext': ['Move This'],
#   'url': ['/wiki/Technotronic', '/wiki/Ya_Kid_K']},
#  {'band_singer': ['Queen'],
#   'ranking': '39',
#   'song': ['"Bohemian Rhapsody"'],
#   'songurl': ['/wiki/Bohemian_Rhapsody'],
#   'titletext': ['Bohemian Rhapsody'],
#   'url': ['/wiki/Queen_(band)']},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '40',
#   'song': ['"Tennessee"'],
#   'songurl': ['/wiki/Tennessee_(Arrested_Development_song)'],
#   'titletext': ['Tennessee (Arrested Development song)'],
#   'url': ['/wiki/Arrested_Development_(group)']},
#  {'band_singer': ['Luther Vandross and Janet Jackson'],
#   'ranking': '41',
#   'song': ['"The Best Things in Life Are Free"'],
#   'songurl': ['/wiki/The_Best_Things_in_Life_Are_Free'],
#   'titletext': ['The Best Things in Life Are Free'],
#   'url': ['/wiki/Luther_Vandross', '/wiki/Janet_Jackson']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '42',
#   'song': ['"Make It Happen"'],
#   'songurl': ['/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#   'titletext': ['Make It Happen (Mariah Carey song)'],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['Elton John'],
#   'ranking': '43',
#   'song': ['"The One"'],
#   'songurl': ['/wiki/The_One_(Elton_John_song)'],
#   'titletext': ['The One (Elton John song)'],
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '44',
#   'song': ['"Set Adrift on Memory Bliss"'],
#   'songurl': ['/wiki/Set_Adrift_on_Memory_Bliss'],
#   'titletext': ['Set Adrift on Memory Bliss'],
#   'url': ['/wiki/P.M._Dawn']},
#  {'band_singer': ['Shakespears Sister'],
#   'ranking': '45',
#   'song': ['"Stay"'],
#   'songurl': ['/wiki/Stay_(Shakespears_Sister_song)'],
#   'titletext': ['Stay (Shakespears Sister song)'],
#   'url': ['/wiki/Shakespears_Sister']},
#  {'band_singer': ['Hammer'],
#   'ranking': '46',
#   'song': ['"2 Legit 2 Quit"'],
#   'songurl': ['/wiki/Too_Legit_to_Quit_(song)'],
#   'titletext': ['Too Legit to Quit (song)'],
#   'url': ['/wiki/MC_Hammer']},
#  {'band_singer': ['KWS'],
#   'ranking': '47',
#   'song': ['"Please Don\'t Go"'],
#   'songurl': ['/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#   'titletext': ["Please Don't Go (KC and the Sunshine Band song)"],
#   'url': ['/wiki/KWS_(band)']},
#  {'band_singer': ['Mint Condition'],
#   'ranking': '48',
#   'song': ['"Breakin\' My Heart (Pretty Brown Eyes)"'],
#   'songurl': ['/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#   'titletext': ["Breakin' My Heart (Pretty Brown Eyes)"],
#   'url': ['/wiki/Mint_Condition']},
#  {'band_singer': ['The Cover Girls'],
#   'ranking': '49',
#   'song': ['"Wishing on a Star"'],
#   'songurl': ['/wiki/Wishing_on_a_Star'],
#   'titletext': ['Wishing on a Star'],
#   'url': ['/wiki/The_Cover_Girls']},
#  {'band_singer': ['Hi-Five'],
#   'ranking': '50',
#   'song': ['"She\'s Playing Hard to Get"'],
#   'songurl': ['/wiki/Hi-Five'],
#   'titletext': ['Hi-Five'],
#   'url': None},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '51',
#   'song': ['"I\'d Die Without You"'],
#   'songurl': ['/wiki/I%27d_Die_Without_You'],
#   'titletext': ["I'd Die Without You"],
#   'url': ['/wiki/P.M._Dawn']},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '52',
#   'song': ['"Good for Me"'],
#   'songurl': ['/wiki/Good_for_Me_(song)'],
#   'titletext': ['Good for Me (song)'],
#   'url': ['/wiki/Amy_Grant']},
#  {'band_singer': ['Toad the Wet Sprocket'],
#   'ranking': '53',
#   'song': ['"All I Want"'],
#   'songurl': ['/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#   'titletext': ['All I Want (Toad the Wet Sprocket song)'],
#   'url': ['/wiki/Toad_the_Wet_Sprocket']},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '54',
#   'song': ['"When a Man Loves a Woman"'],
#   'songurl': ['/wiki/When_a_Man_Loves_a_Woman_(song)'],
#   'titletext': ['When a Man Loves a Woman (song)'],
#   'url': ['/wiki/Michael_Bolton']},
#  {'band_singer': ['Genesis'],
#   'ranking': '55',
#   'song': ['"I Can\'t Dance"'],
#   'songurl': ['/wiki/I_Can%27t_Dance'],
#   'titletext': ["I Can't Dance"],
#   'url': ['/wiki/Genesis_(band)']},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '56',
#   'song': ['"Hazard"'],
#   'songurl': ['/wiki/Hazard_(song)'],
#   'titletext': ['Hazard (song)'],
#   'url': ['/wiki/Richard_Marx']},
#  {'band_singer': ['U2'],
#   'ranking': '57',
#   'song': ['"Mysterious Ways"'],
#   'songurl': ['/wiki/Mysterious_Ways_(song)'],
#   'titletext': ['Mysterious Ways (song)'],
#   'url': ['/wiki/U2']},
#  {'band_singer': ['George Michael'],
#   'ranking': '58',
#   'song': ['"Too Funky"'],
#   'songurl': ['/wiki/Too_Funky'],
#   'titletext': ['Too Funky'],
#   'url': ['/wiki/George_Michael']},
#  {'band_singer': ['The Heights'],
#   'ranking': '59',
#   'song': ['"How Do You Talk to an Angel"'],
#   'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#   'titletext': ['How Do You Talk to an Angel'],
#   'url': ['/wiki/The_Heights_(TV_series)']},
#  {'band_singer': ['U2'],
#   'ranking': '60',
#   'song': ['"One"'],
#   'songurl': ['/wiki/One_(U2_song)'],
#   'titletext': ['One (U2 song)'],
#   'url': ['/wiki/U2']},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '61',
#   'song': ['"Keep on Walkin\'"'],
#   'songurl': ['/wiki/Keep_on_Walkin%27_(song)'],
#   'titletext': ["Keep on Walkin' (song)"],
#   'url': ['/wiki/CeCe_Peniston']},
#  {'band_singer': ['Genesis'],
#   'ranking': '62',
#   'song': ['"Hold on My Heart"'],
#   'songurl': ['/wiki/Hold_on_My_Heart'],
#   'titletext': ['Hold on My Heart'],
#   'url': ['/wiki/Genesis_(band)']},
#  {'band_singer': ['Karyn White'],
#   'ranking': '63',
#   'song': ['"The Way I Feel About You"'],
#   'songurl': ['/wiki/Karyn_White'],
#   'titletext': ['Karyn White'],
#   'url': None},
#  {'band_singer': ['Celine Dion and Peabo Bryson'],
#   'ranking': '64',
#   'song': ['"Beauty and the Beast"'],
#   'songurl': ['/wiki/Beauty_and_the_Beast_(Disney_song)'],
#   'titletext': ['Beauty and the Beast (Disney song)'],
#   'url': ['/wiki/Celine_Dion', '/wiki/Peabo_Bryson']},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '65',
#   'song': ['"Warm It Up"'],
#   'songurl': ['/wiki/Warm_It_Up'],
#   'titletext': ['Warm It Up'],
#   'url': ['/wiki/Kris_Kross']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '66',
#   'song': ['"In the Closet"'],
#   'songurl': ['/wiki/In_the_Closet'],
#   'titletext': ['In the Closet'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '67',
#   'song': ['"People Everyday"'],
#   'songurl': ['/wiki/People_Everyday'],
#   'titletext': ['People Everyday'],
#   'url': ['/wiki/Arrested_Development_(group)']},
#  {'band_singer': ['Genesis'],
#   'ranking': '68',
#   'song': ['"No Son of Mine"'],
#   'songurl': ['/wiki/No_Son_of_Mine'],
#   'titletext': ['No Son of Mine'],
#   'url': ['/wiki/Genesis_(band)']},
#  {'band_singer': ['Marky Mark and the Funky Bunch'],
#   'ranking': '69',
#   'song': ['"Wildside"'],
#   'songurl': ['/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#   'titletext': ['Wildside (Marky Mark and the Funky Bunch song)'],
#   'url': ['/wiki/Marky_Mark_and_the_Funky_Bunch']},
#  {'band_singer': ['Bryan Adams'],
#   'ranking': '70',
#   'song': ['"Do I Have to Say the Words?"'],
#   'songurl': ['/wiki/Do_I_Have_to_Say_the_Words%3F'],
#   'titletext': ['Do I Have to Say the Words?'],
#   'url': ['/wiki/Bryan_Adams']},
#  {'band_singer': ['The Cure'],
#   'ranking': '71',
#   'song': ['"Friday I\'m in Love"'],
#   'songurl': ['/wiki/Friday_I%27m_in_Love'],
#   'titletext': ["Friday I'm in Love"],
#   'url': ['/wiki/The_Cure']},
#  {'band_singer': ['Ugly Kid Joe'],
#   'ranking': '72',
#   'song': ['"Everything About You"'],
#   'songurl': ['/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#   'titletext': ['Everything About You (Ugly Kid Joe song)'],
#   'url': ['/wiki/Ugly_Kid_Joe']},
#  {'band_singer': ['Paula Abdul'],
#   'ranking': '73',
#   'song': ['"Blowing Kisses in the Wind"'],
#   'songurl': ['/wiki/Blowing_Kisses_in_the_Wind'],
#   'titletext': ['Blowing Kisses in the Wind'],
#   'url': ['/wiki/Paula_Abdul']},
#  {'band_singer': ['Bryan Adams'],
#   'ranking': '74',
#   'song': ['"Thought I\'d Died and Gone to Heaven"'],
#   'songurl': ['/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#   'titletext': ["Thought I'd Died and Gone to Heaven"],
#   'url': ['/wiki/Bryan_Adams']},
#  {'band_singer': ['Snap!'],
#   'ranking': '75',
#   'song': ['"Rhythm Is a Dancer"'],
#   'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#   'titletext': ['Rhythm Is a Dancer'],
#   'url': ['/wiki/Snap!']},
#  {'band_singer': ['Hammer'],
#   'ranking': '76',
#   'song': ['"Addams Groove"'],
#   'songurl': ['/wiki/Addams_Groove'],
#   'titletext': ['Addams Groove'],
#   'url': ['/wiki/MC_Hammer']},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '77',
#   'song': ['"Missing You Now"'],
#   'songurl': ['/wiki/Missing_You_Now'],
#   'titletext': ['Missing You Now'],
#   'url': ['/wiki/Michael_Bolton']},
#  {'band_singer': ['N2Deep'],
#   'ranking': '78',
#   'song': ['"Back to the Hotel"'],
#   'songurl': ['/wiki/N2Deep'],
#   'titletext': ['N2Deep'],
#   'url': None},
#  {'band_singer': ['Kathy Troccoli'],
#   'ranking': '79',
#   'song': ['"Everything Changes"'],
#   'songurl': ['/wiki/Kathy_Troccoli'],
#   'titletext': ['Kathy Troccoli'],
#   'url': None},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '80',
#   'song': ['"Have You Ever Needed Someone So Bad"'],
#   'songurl': ['/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#   'titletext': ['Have You Ever Needed Someone So Bad'],
#   'url': ['/wiki/Def_Leppard']},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '81',
#   'song': ['"Take This Heart"'],
#   'songurl': ['/wiki/Take_This_Heart'],
#   'titletext': ['Take This Heart'],
#   'url': ['/wiki/Richard_Marx']},
#  {'band_singer': ['FireHouse'],
#   'ranking': '82',
#   'song': ['"When I Look Into Your Eyes"'],
#   'songurl': ['/wiki/When_I_Look_Into_Your_Eyes'],
#   'titletext': ['When I Look Into Your Eyes'],
#   'url': ['/wiki/FireHouse_(band)']},
#  {'band_singer': ['Jade'],
#   'ranking': '83',
#   'song': ['"I Wanna Love You"'],
#   'songurl': ['/wiki/I_Wanna_Love_You_(Jade_song)'],
#   'titletext': ['I Wanna Love You (Jade song)'],
#   'url': ['/wiki/Jade_(American_band)']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '84',
#   'song': ['"Uhh Ahh"'],
#   'songurl': ['/wiki/Uhh_Ahh'],
#   'titletext': ['Uhh Ahh'],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Mary J. Blige'],
#   'ranking': '85',
#   'song': ['"Real Love"'],
#   'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#   'titletext': ['Real Love (Mary J. Blige song)'],
#   'url': ['/wiki/Mary_J._Blige']},
#  {'band_singer': ['The KLF'],
#   'ranking': '86',
#   'song': ['"Justified and Ancient"'],
#   'songurl': ['/wiki/Justified_and_Ancient'],
#   'titletext': ['Justified and Ancient'],
#   'url': ['/wiki/The_KLF']},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '87',
#   'song': ['"Slow Motion"'],
#   'songurl': ['/wiki/Color_Me_Badd'],
#   'titletext': ['Color Me Badd'],
#   'url': None},
#  {'band_singer': ['TLC'],
#   'ranking': '88',
#   'song': ['"What About Your Friends"'],
#   'songurl': ['/wiki/What_About_Your_Friends'],
#   'titletext': ['What About Your Friends'],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Color Me Badd'],
#   'ranking': '89',
#   'song': ['"Thinkin\' Back"'],
#   'songurl': ['/wiki/Color_Me_Badd'],
#   'titletext': ['Color Me Badd'],
#   'url': None},
#  {'band_singer': ['Charles & Eddie'],
#   'ranking': '90',
#   'song': ['"Would I Lie to You?"'],
#   'songurl': ['/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#   'titletext': ['Would I Lie to You? (Charles & Eddie song)'],
#   'url': ['/wiki/Charles_%26_Eddie']},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '91',
#   'song': ['"That\'s What Love Is For"'],
#   'songurl': ['/wiki/That%27s_What_Love_Is_For'],
#   'titletext': ["That's What Love Is For"],
#   'url': ['/wiki/Amy_Grant']},
#  {'band_singer': ['Richard Marx'],
#   'ranking': '92',
#   'song': ['"Keep Coming Back"'],
#   'songurl': ['/wiki/Keep_Coming_Back_(song)'],
#   'titletext': ['Keep Coming Back (song)'],
#   'url': ['/wiki/Richard_Marx']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '93',
#   'song': ['"Free Your Mind"'],
#   'songurl': ['/wiki/Free_Your_Mind_(song)'],
#   'titletext': ['Free Your Mind (song)'],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Keith Sweat'],
#   'ranking': '94',
#   'song': ['"Keep It Comin\'"'],
#   'songurl': ['/wiki/Keep_It_Comin%27_(song)'],
#   'titletext': ["Keep It Comin' (song)"],
#   'url': ['/wiki/Keith_Sweat']},
#  {'band_singer': ['Mr. Big'],
#   'ranking': '95',
#   'song': ['"Just Take My Heart"'],
#   'songurl': ['/wiki/Mr._Big_(band)'],
#   'titletext': ['Mr. Big (band)'],
#   'url': None},
#  {'band_singer': ['Amy Grant'],
#   'ranking': '96',
#   'song': ['"I Will Remember You"'],
#   'songurl': ['/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#   'titletext': ['I Will Remember You (Amy Grant song)'],
#   'url': ['/wiki/Amy_Grant']},
#  {'band_singer': ['CeCe Peniston'],
#   'ranking': '97',
#   'song': ['"We Got a Love Thang"'],
#   'songurl': ['/wiki/We_Got_a_Love_Thang'],
#   'titletext': ['We Got a Love Thang'],
#   'url': ['/wiki/CeCe_Peniston']},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '98',
#   'song': ['"Let\'s Get Rocked"'],
#   'songurl': ['/wiki/Let%27s_Get_Rocked'],
#   'titletext': ["Let's Get Rocked"],
#   'url': ['/wiki/Def_Leppard']},
#  {'band_singer': ['Das EFX'],
#   'ranking': '99',
#   'song': ['"They Want EFX"'],
#   'songurl': ['/wiki/They_Want_EFX'],
#   'titletext': ['They Want EFX'],
#   'url': ['/wiki/Das_EFX']},
#  {'band_singer': ['Bonnie Raitt'],
#   'ranking': '100',
#   'song': ['"I Can\'t Make You Love Me"'],
#   'songurl': ['/wiki/I_Can%27t_Make_You_Love_Me'],
#   'titletext': ["I Can't Make You Love Me"],
#   'url': ['/wiki/Bonnie_Raitt']},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': '1',
#   'song': ['"I Will Always Love You"'],
#   'songurl': ['/wiki/I_Will_Always_Love_You#Whitney_Houston_version'],
#   'titletext': ['I Will Always Love You'],
#   'url': ['/wiki/Whitney_Houston']},
#  {'band_singer': ['Tag Team'],
#   'ranking': '2',
#   'song': ['"Whoomp! (There It Is)"'],
#   'songurl': ['/wiki/Whoomp!_(There_It_Is)'],
#   'titletext': ['Whoomp! (There It Is)'],
#   'url': ['/wiki/Tag_Team_(group)']},
#  {'band_singer': ['UB40'],
#   'ranking': '3',
#   'song': ['"Can\'t Help Falling in Love"'],
#   'songurl': ['/wiki/Can%27t_Help_Falling_in_Love'],
#   'titletext': ["Can't Help Falling in Love"],
#   'url': ['/wiki/UB40']},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '4',
#   'song': ['"That\'s the Way Love Goes"'],
#   'songurl': ['/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'],
#   'titletext': ["That's the Way Love Goes (Janet Jackson song)"],
#   'url': ['/wiki/Janet_Jackson']},
#  {'band_singer': ['Silk'],
#   'ranking': '5',
#   'song': ['"Freak Me"'],
#   'songurl': ['/wiki/Freak_Me'],
#   'titletext': ['Freak Me'],
#   'url': ['/wiki/Silk_(group)']},
#  {'band_singer': ['SWV'],
#   'ranking': '6',
#   'song': ['"Weak"'],
#   'songurl': ['/wiki/Weak_(SWV_song)'],
#   'titletext': ['Weak (SWV song)'],
#   'url': ['/wiki/SWV']},
#  {'band_singer': ['Shai'],
#   'ranking': '7',
#   'song': ['"If I Ever Fall in Love"'],
#   'songurl': ['/wiki/If_I_Ever_Fall_in_Love'],
#   'titletext': ['If I Ever Fall in Love'],
#   'url': ['/wiki/Shai_(band)']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '8',
#   'song': ['"Dreamlover"'],
#   'songurl': ['/wiki/Dreamlover_(song)'],
#   'titletext': ['Dreamlover (song)'],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['Wreckx-n-Effect'],
#   'ranking': '9',
#   'song': ['"Rump Shaker"'],
#   'songurl': ['/wiki/Rump_Shaker_(song)'],
#   'titletext': ['Rump Shaker (song)'],
#   'url': ['/wiki/Wreckx-n-Effect']},
#  {'band_singer': ['Snow'],
#   'ranking': '10',
#   'song': ['"Informer"'],
#   'songurl': ['/wiki/Informer_(song)'],
#   'titletext': ['Informer (song)'],
#   'url': ['/wiki/Snow_(musician)']},
#  {'band_singer': ['Dr. Dre'],
#   'ranking': '11',
#   'song': ['"Nuthin\' but a \'G\' Thang"'],
#   'songurl': ['/wiki/Nuthin%27_but_a_%27G%27_Thang'],
#   'titletext': ["Nuthin' but a 'G' Thang"],
#   'url': ['/wiki/Dr._Dre']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '12',
#   'song': ['"In the Still of the Nite"'],
#   'songurl': ['/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'],
#   'titletext': ['In the Still of the Night (1956 song)'],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Jade'],
#   'ranking': '13',
#   'song': ['"Don\'t Walk Away"'],
#   'songurl': ['/wiki/Don%27t_Walk_Away_(Jade_song)'],
#   'titletext': ["Don't Walk Away (Jade song)"],
#   'url': ['/wiki/Jade_(American_band)']},
#  {'band_singer': ['H-Town'],
#   'ranking': '14',
#   'song': ['"Knockin\' da Boots"'],
#   'songurl': ['/wiki/Knockin%27_da_Boots'],
#   'titletext': ["Knockin' da Boots"],
#   'url': ['/wiki/H-Town_(band)']},
#  {'band_singer': ['Jodeci'],
#   'ranking': '15',
#   'song': ['"Lately"'],
#   'songurl': ['/wiki/Lately_(Jodeci_song)'],
#   'titletext': ['Lately (Jodeci song)'],
#   'url': ['/wiki/Jodeci']},
#  {'band_singer': ['Duice'],
#   'ranking': '16',
#   'song': ['"Dazzey Duks"'],
#   'songurl': ['/wiki/Dazzey_Duks'],
#   'titletext': ['Dazzey Duks'],
#   'url': ['/wiki/Duice']},
#  {'band_singer': ['Robin S.'],
#   'ranking': '17',
#   'song': ['"Show Me Love"'],
#   'songurl': ['/wiki/Show_Me_Love_(Robin_S._song)'],
#   'titletext': ['Show Me Love (Robin S. song)'],
#   'url': ['/wiki/Robin_S.']},
#  {'band_singer': ['Peabo Bryson and Regina Belle'],
#   'ranking': '18',
#   'song': ['"A Whole New World"'],
#   'songurl': ['/wiki/A_Whole_New_World'],
#   'titletext': ['A Whole New World'],
#   'url': ['/wiki/Peabo_Bryson', '/wiki/Regina_Belle']},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '19',
#   'song': ['"If"'],
#   'songurl': ['/wiki/If_(Janet_Jackson_song)'],
#   'titletext': ['If (Janet Jackson song)'],
#   'url': ['/wiki/Janet_Jackson']},
#  {'band_singer': ['SWV'],
#   'ranking': '20',
#   'song': ['"I\'m So Into You"'],
#   'songurl': ['/wiki/I%27m_So_Into_You'],
#   'titletext': ["I'm So Into You"],
#   'url': ['/wiki/SWV']},
#  {'band_singer': ['Vanessa Williams and Brian McKnight'],
#   'ranking': '21',
#   'song': ['"Love Is"'],
#   'songurl': ['/wiki/Love_Is_(Vanessa_Williams_song)'],
#   'titletext': ['Love Is (Vanessa Williams song)'],
#   'url': ['/wiki/Vanessa_L._Williams', '/wiki/Brian_McKnight']},
#  {'band_singer': ['Soul Asylum'],
#   'ranking': '22',
#   'song': ['"Runaway Train"'],
#   'songurl': ['/wiki/Runaway_Train_(Soul_Asylum_song)'],
#   'titletext': ['Runaway Train (Soul Asylum song)'],
#   'url': ['/wiki/Soul_Asylum']},
#  {'band_singer': ['Exposé'],
#   'ranking': '23',
#   'song': ['"I\'ll Never Get Over You (Getting Over Me)"'],
#   'songurl': ['/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'],
#   'titletext': ["I'll Never Get Over You (Getting Over Me)"],
#   'url': ['/wiki/Expos%C3%A9_(group)']},
#  {'band_singer': ['Paperboy'],
#   'ranking': '24',
#   'song': ['"Ditty"'],
#   'songurl': ['/wiki/Ditty_(Paperboy_song)'],
#   'titletext': ['Ditty (Paperboy song)'],
#   'url': ['/wiki/Paperboy_(rapper)']},
#  {'band_singer': ['Snap!'],
#   'ranking': '25',
#   'song': ['"Rhythm Is a Dancer"'],
#   'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#   'titletext': ['Rhythm Is a Dancer'],
#   'url': ['/wiki/Snap!']},
#  {'band_singer': ['Billy Joel'],
#   'ranking': '26',
#   'song': ['"The River of Dreams"'],
#   'songurl': ['/wiki/The_River_of_Dreams'],
#   'titletext': ['The River of Dreams'],
#   'url': ['/wiki/Billy_Joel']},
#  {'band_singer': ['The Proclaimers'],
#   'ranking': '27',
#   'song': ['"I\'m Gonna Be (500 Miles)"'],
#   'songurl': ['/wiki/I%27m_Gonna_Be_(500_Miles)'],
#   'titletext': ["I'm Gonna Be (500 Miles)"],
#   'url': ['/wiki/The_Proclaimers']},
#  {'band_singer': ['Spin Doctors'],
#   'ranking': '28',
#   'song': ['"Two Princes"'],
#   'songurl': ['/wiki/Two_Princes'],
#   'titletext': ['Two Princes'],
#   'url': ['/wiki/Spin_Doctors']},
#  {'band_singer': ['SWV'],
#   'ranking': '29',
#   'song': ['"Right Here"'],
#   'songurl': ['/wiki/Right_Here_(SWV_song)'],
#   'titletext': ['Right Here (SWV song)'],
#   'url': ['/wiki/SWV']},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': '30',
#   'song': ['"I Have Nothing"'],
#   'songurl': ['/wiki/I_Have_Nothing'],
#   'titletext': ['I Have Nothing'],
#   'url': ['/wiki/Whitney_Houston']},
#  {'band_singer': ['Arrested Development'],
#   'ranking': '31',
#   'song': ['"Mr. Wendal"'],
#   'songurl': ['/wiki/Mr._Wendal'],
#   'titletext': ['Mr. Wendal'],
#   'url': ['/wiki/Arrested_Development_(group)']},
#  {'band_singer': ['Rod Stewart'],
#   'ranking': '32',
#   'song': ['"Have I Told You Lately"'],
#   'songurl': ['/wiki/Have_I_Told_You_Lately'],
#   'titletext': ['Have I Told You Lately'],
#   'url': ['/wiki/Rod_Stewart']},
#  {'band_singer': ['Shanice'],
#   'ranking': '33',
#   'song': ['"Saving Forever for You"'],
#   'songurl': ['/wiki/Saving_Forever_for_You'],
#   'titletext': ['Saving Forever for You'],
#   'url': ['/wiki/Shanice']},
#  {'band_singer': ['Duran Duran'],
#   'ranking': '34',
#   'song': ['"Ordinary World"'],
#   'songurl': ['/wiki/Ordinary_World'],
#   'titletext': ['Ordinary World'],
#   'url': ['/wiki/Duran_Duran']},
#  {'band_singer': ['Tony! Toni! Toné!'],
#   'ranking': '35',
#   'song': ['"If I Had No Loot"'],
#   'songurl': ['/wiki/If_I_Had_No_Loot'],
#   'titletext': ['If I Had No Loot'],
#   'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!']},
#  {'band_singer': ['Meat Loaf'],
#   'ranking': '36',
#   'song': ['"I\'d Do Anything for Love (But I Won\'t Do That)"'],
#   'songurl': ['/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'],
#   'titletext': ["I'd Do Anything for Love (But I Won't Do That)"],
#   'url': ['/wiki/Meat_Loaf']},
#  {'band_singer': ['Onyx'],
#   'ranking': '37',
#   'song': ['"Slam"'],
#   'songurl': ['/wiki/Slam_(Onyx_song)'],
#   'titletext': ['Slam (Onyx song)'],
#   'url': ['/wiki/Onyx_(group)']},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '38',
#   'song': ['"Looking Through Patient Eyes"'],
#   'songurl': ['/wiki/Looking_Through_Patient_Eyes'],
#   'titletext': ['Looking Through Patient Eyes'],
#   'url': ['/wiki/P.M._Dawn']},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': '39',
#   'song': ['"I\'m Every Woman"'],
#   'songurl': ['/wiki/I%27m_Every_Woman#Whitney_Houston_version'],
#   'titletext': ["I'm Every Woman"],
#   'url': ['/wiki/Whitney_Houston']},
#  {'band_singer': ['Shai'],
#   'ranking': '40',
#   'song': ['"Baby I\'m Yours"'],
#   'songurl': ['/wiki/Shai_(band)'],
#   'titletext': ['Shai (band)'],
#   'url': None},
#  {'band_singer': ['Duran Duran'],
#   'ranking': '41',
#   'song': ['"Come Undone"'],
#   'songurl': ['/wiki/Come_Undone_(Duran_Duran_song)'],
#   'titletext': ['Come Undone (Duran Duran song)'],
#   'url': ['/wiki/Duran_Duran']},
#  {'band_singer': ['Tina Turner'],
#   'ranking': '42',
#   'song': ['"I Don\'t Wanna Fight"'],
#   'songurl': ['/wiki/I_Don%27t_Wanna_Fight'],
#   'titletext': ["I Don't Wanna Fight"],
#   'url': ['/wiki/Tina_Turner']},
#  {'band_singer': ['P.M. Dawn'],
#   'ranking': '43',
#   'song': ['"I\'d Die Without You"'],
#   'songurl': ['/wiki/I%27d_Die_Without_You'],
#   'titletext': ["I'd Die Without You"],
#   'url': ['/wiki/P.M._Dawn']},
#  {'band_singer': ['95 South'],
#   'ranking': '44',
#   'song': ['"Whoot, There It Is"'],
#   'songurl': ['/wiki/Whoot,_There_It_Is'],
#   'titletext': ['Whoot, There It Is'],
#   'url': ['/wiki/95_South']},
#  {'band_singer': ['Naughty by Nature'],
#   'ranking': '45',
#   'song': ['"Hip Hop Hooray"'],
#   'songurl': ['/wiki/Hip_Hop_Hooray'],
#   'titletext': ['Hip Hop Hooray'],
#   'url': ['/wiki/Naughty_by_Nature']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': '46',
#   'song': ['"Another Sad Love Song"'],
#   'songurl': ['/wiki/Another_Sad_Love_Song'],
#   'titletext': ['Another Sad Love Song'],
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Michael Jackson'],
#   'ranking': '47',
#   'song': ['"Will You Be There"'],
#   'songurl': ['/wiki/Will_You_Be_There'],
#   'titletext': ['Will You Be There'],
#   'url': ['/wiki/Michael_Jackson']},
#  {'band_singer': ['Shai'],
#   'ranking': '48',
#   'song': ['"Comforter"'],
#   'songurl': ['/wiki/Comforter_(song)'],
#   'titletext': ['Comforter (song)'],
#   'url': ['/wiki/Shai_(band)']},
#  {'band_singer': ['Bobby Brown'],
#   'ranking': '49',
#   'song': ['"Good Enough"'],
#   'songurl': ['/wiki/Bobby_Brown'],
#   'titletext': ['Bobby Brown'],
#   'url': None},
#  {'band_singer': ['4 Non Blondes'],
#   'ranking': '50',
#   'song': ['"What\'s up"'],
#   'songurl': ['/wiki/What%27s_Up%3F_(song)'],
#   'titletext': ["What's Up? (song)"],
#   'url': ['/wiki/4_Non_Blondes']},
#  {'band_singer': ['Ace of Base'],
#   'ranking': '51',
#   'song': ['"All That She Wants"'],
#   'songurl': ['/wiki/All_That_She_Wants'],
#   'titletext': ['All That She Wants'],
#   'url': ['/wiki/Ace_of_Base']},
#  {'band_singer': ['Prince and The New Power Generation'],
#   'ranking': '52',
#   'song': ['"7"'],
#   'songurl': ['/wiki/7_(song)'],
#   'titletext': ['7 (song)'],
#   'url': ['/wiki/Prince_(musician)', '/wiki/The_New_Power_Generation']},
#  {'band_singer': ['Dr. Dre ', ' Snoop Doggy Dogg'],
#   'ranking': '53',
#   'song': ['"Dre Day"'],
#   'songurl': ['/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'],
#   'titletext': ["Fuck wit Dre Day (And Everybody's Celebratin')"],
#   'url': ['/wiki/Dr._Dre', '/wiki/Snoop_Dogg']},
#  {'band_singer': ['Brian McKnight'],
#   'ranking': '54',
#   'song': ['"One Last Cry"'],
#   'songurl': ['/wiki/One_Last_Cry'],
#   'titletext': ['One Last Cry'],
#   'url': ['/wiki/Brian_McKnight']},
#  {'band_singer': ['Xscape'],
#   'ranking': '55',
#   'song': ['"Just Kickin\' It"'],
#   'songurl': ['/wiki/Just_Kickin%27_It'],
#   'titletext': ["Just Kickin' It"],
#   'url': ['/wiki/Xscape_(band)']},
#  {'band_singer': ['2Pac'],
#   'ranking': '56',
#   'song': ['"I Get Around"'],
#   'songurl': ['/wiki/I_Get_Around_(Tupac_Shakur_song)'],
#   'titletext': ['I Get Around (Tupac Shakur song)'],
#   'url': ['/wiki/Tupac_Shakur']},
#  {'band_singer': ['Bon Jovi'],
#   'ranking': '57',
#   'song': ['"Bed of Roses"'],
#   'songurl': ['/wiki/Bed_of_Roses_(song)'],
#   'titletext': ['Bed of Roses (song)'],
#   'url': ['/wiki/Bon_Jovi']},
#  {'band_singer': ['Mary J. Blige'],
#   'ranking': '58',
#   'song': ['"Real Love"'],
#   'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#   'titletext': ['Real Love (Mary J. Blige song)'],
#   'url': ['/wiki/Mary_J._Blige']},
#  {'band_singer': ['Portrait'],
#   'ranking': '59',
#   'song': ['"Here We Go Again!"'],
#   'songurl': ['/wiki/Portrait_(group)'],
#   'titletext': ['Portrait (group)'],
#   'url': None},
#  {'band_singer': ['Aerosmith'],
#   'ranking': '60',
#   'song': ['"Cryin\'"'],
#   'songurl': ['/wiki/Cryin%27'],
#   'titletext': ["Cryin'"],
#   'url': ['/wiki/Aerosmith']},
#  {'band_singer': ['Ugly Kid Joe'],
#   'ranking': '61',
#   'song': ['"Cat\'s in the Cradle"'],
#   'songurl': ['/wiki/Cat%27s_in_the_Cradle'],
#   'titletext': ["Cat's in the Cradle"],
#   'url': ['/wiki/Ugly_Kid_Joe']},
#  {'band_singer': ['TLC'],
#   'ranking': '62',
#   'song': ['"What About Your Friends"'],
#   'songurl': ['/wiki/What_About_Your_Friends'],
#   'titletext': ['What About Your Friends'],
#   'url': ['/wiki/TLC_(band)']},
#  {'band_singer': ['Positive K'],
#   'ranking': '63',
#   'song': ['"I Got a Man"'],
#   'songurl': ['/wiki/I_Got_a_Man'],
#   'titletext': ['I Got a Man'],
#   'url': ['/wiki/Positive_K']},
#  {'band_singer': ['Zhané'],
#   'ranking': '64',
#   'song': ['"Hey Mr. D.J."'],
#   'songurl': ['/wiki/Hey_Mr._D.J.'],
#   'titletext': ['Hey Mr. D.J.'],
#   'url': ['/wiki/Zhan%C3%A9']},
#  {'band_singer': ['Cypress Hill'],
#   'ranking': '65',
#   'song': ['"Insane in the Brain"'],
#   'songurl': ['/wiki/Insane_in_the_Brain'],
#   'titletext': ['Insane in the Brain'],
#   'url': ['/wiki/Cypress_Hill']},
#  {'band_singer': ['Madonna'],
#   'ranking': '66',
#   'song': ['"Deeper and Deeper"'],
#   'songurl': ['/wiki/Deeper_and_Deeper'],
#   'titletext': ['Deeper and Deeper'],
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Madonna'],
#   'ranking': '67',
#   'song': ['"Rain"'],
#   'songurl': ['/wiki/Rain_(Madonna_song)'],
#   'titletext': ['Rain (Madonna song)'],
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Jeremy Jordan'],
#   'ranking': '68',
#   'song': ['"The Right Kind of Love"'],
#   'songurl': ['/wiki/The_Right_Kind_of_Love'],
#   'titletext': ['The Right Kind of Love'],
#   'url': ['/wiki/Jeremy_Jordan_(singer)']},
#  {'band_singer': ['Inner Circle'],
#   'ranking': '69',
#   'song': ['"Bad Boys"'],
#   'songurl': ['/wiki/Bad_Boys_(Inner_Circle_song)'],
#   'titletext': ['Bad Boys (Inner Circle song)'],
#   'url': ['/wiki/Inner_Circle_(reggae_band)']},
#  {'band_singer': ['Boy Krazy'],
#   'ranking': '70',
#   'song': ['"That\'s What Love Can Do"'],
#   'songurl': ['/wiki/That%27s_What_Love_Can_Do'],
#   'titletext': ["That's What Love Can Do"],
#   'url': ['/wiki/Boy_Krazy']},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '71',
#   'song': ['"Do You Believe in Us"'],
#   'songurl': ['/wiki/Do_You_Believe_in_Us'],
#   'titletext': ['Do You Believe in Us'],
#   'url': ['/wiki/Jon_Secada']},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '72',
#   'song': ['"Angel"'],
#   'songurl': ['/wiki/Angel_(Jon_Secada_song)'],
#   'titletext': ['Angel (Jon Secada song)'],
#   'url': ['/wiki/Jon_Secada']},
#  {'band_singer': ['Kenny G'],
#   'ranking': '73',
#   'song': ['"Forever in Love"'],
#   'songurl': ['/wiki/Forever_in_Love_(instrumental)'],
#   'titletext': ['Forever in Love (instrumental)'],
#   'url': ['/wiki/Kenny_G']},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '74',
#   'song': ['"Again"'],
#   'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#   'titletext': ['Again (Janet Jackson song)'],
#   'url': ['/wiki/Janet_Jackson']},
#  {'band_singer': ['DJ Jazzy Jeff & The Fresh Prince'],
#   'ranking': '75',
#   'song': ['"Boom! Shake the Room"'],
#   'songurl': ['/wiki/Boom!_Shake_the_Room'],
#   'titletext': ['Boom! Shake the Room'],
#   'url': ['/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince']},
#  {'band_singer': ['Restless Heart'],
#   'ranking': '76',
#   'song': ['"When She Cries"'],
#   'songurl': ['/wiki/When_She_Cries'],
#   'titletext': ['When She Cries'],
#   'url': ['/wiki/Restless_Heart']},
#  {'band_singer': ['Inner Circle'],
#   'ranking': '77',
#   'song': ['"Sweat (A La La La La Long)"'],
#   'songurl': ['/wiki/Sweat_(A_La_La_La_La_Long)'],
#   'titletext': ['Sweat (A La La La La Long)'],
#   'url': ['/wiki/Inner_Circle_(reggae_band)']},
#  {'band_singer': ['Ice Cube'],
#   'ranking': '78',
#   'song': ['"It Was a Good Day"'],
#   'songurl': ['/wiki/It_Was_a_Good_Day'],
#   'titletext': ['It Was a Good Day'],
#   'url': ['/wiki/Ice_Cube']},
#  {'band_singer': ['Captain Hollywood Project'],
#   'ranking': '79',
#   'song': ['"More and More"'],
#   'songurl': ['/wiki/More_and_More_(Captain_Hollywood_Project_song)'],
#   'titletext': ['More and More (Captain Hollywood Project song)'],
#   'url': ['/wiki/Captain_Hollywood_Project']},
#  {'band_singer': ['The Heights'],
#   'ranking': '80',
#   'song': ['"How Do You Talk to an Angel"'],
#   'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#   'titletext': ['How Do You Talk to an Angel'],
#   'url': ['/wiki/The_Heights_(TV_series)']},
#  {'band_singer': ['Digable Planets'],
#   'ranking': '81',
#   'song': ['"Rebirth of Slick (Cool Like Dat)"'],
#   'songurl': ['/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'],
#   'titletext': ['Rebirth of Slick (Cool Like Dat)'],
#   'url': ['/wiki/Digable_Planets']},
#  {'band_singer': ['Haddaway'],
#   'ranking': '82',
#   'song': ['"What Is Love"'],
#   'songurl': ['/wiki/What_Is_Love_(Haddaway_song)'],
#   'titletext': ['What Is Love (Haddaway song)'],
#   'url': ['/wiki/Haddaway']},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': '83',
#   'song': ['"To Love Somebody"'],
#   'songurl': ['/wiki/To_Love_Somebody_(song)'],
#   'titletext': ['To Love Somebody (song)'],
#   'url': ['/wiki/Michael_Bolton']},
#  {'band_singer': ['En Vogue'],
#   'ranking': '84',
#   'song': ['"Give It Up, Turn It Loose"'],
#   'songurl': ['/wiki/Give_It_Up,_Turn_It_Loose'],
#   'titletext': ['Give It Up, Turn It Loose'],
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Kris Kross'],
#   'ranking': '85',
#   'song': ['"Alright"'],
#   'songurl': ['/wiki/Alright_(Kris_Kross_song)'],
#   'titletext': ['Alright (Kris Kross song)'],
#   'url': ['/wiki/Kris_Kross']},
#  {'band_singer': ['Ice Cube ', ' Das EFX'],
#   'ranking': '86',
#   'song': ['"Check Yo Self"'],
#   'songurl': ['/wiki/Check_Yo_Self'],
#   'titletext': ['Check Yo Self'],
#   'url': ['/wiki/Ice_Cube', '/wiki/Das_EFX']},
#  {'band_singer': ['Sting'],
#   'ranking': '87',
#   'song': ['"Fields of Gold"'],
#   'songurl': ['/wiki/Fields_of_Gold'],
#   'titletext': ['Fields of Gold'],
#   'url': ['/wiki/Sting_(musician)']},
#  {'band_singer': ['Dino'],
#   'ranking': '88',
#   'song': ['"Ooh Child"'],
#   'songurl': ['/wiki/Ooh_Child'],
#   'titletext': ['Ooh Child'],
#   'url': ['/wiki/Dino_(singer)']},
#  {'band_singer': ['Go West'],
#   'ranking': '89',
#   'song': ['"Faithful"'],
#   'songurl': ['/wiki/Faithful_(Go_West_song)'],
#   'titletext': ['Faithful (Go West song)'],
#   'url': ['/wiki/Go_West_(band)']},
#  {'band_singer': ['Rod Stewart'],
#   'ranking': '90',
#   'song': ['"Reason to Believe"'],
#   'songurl': ['/wiki/Reason_to_Believe'],
#   'titletext': ['Reason to Believe'],
#   'url': ['/wiki/Rod_Stewart']},
#  {'band_singer': ['Tears for Fears'],
#   'ranking': '91',
#   'song': ['"Break It Down Again"'],
#   'songurl': ['/wiki/Break_It_Down_Again'],
#   'titletext': ['Break It Down Again'],
#   'url': ['/wiki/Tears_for_Fears']},
#  {'band_singer': ['Joey Lawrence'],
#   'ranking': '92',
#   'song': ['"Nothin\' My Love Can\'t Fix"'],
#   'songurl': ['/wiki/Nothin%27_My_Love_Can%27t_Fix'],
#   'titletext': ["Nothin' My Love Can't Fix"],
#   'url': ['/wiki/Joey_Lawrence']},
#  {'band_singer': ['Green Jellÿ'],
#   'ranking': '93',
#   'song': ['"Three Little Pigs"'],
#   'songurl': ['/wiki/Three_Little_Pigs_(song)'],
#   'titletext': ['Three Little Pigs (song)'],
#   'url': ['/wiki/Green_Jell%C3%BF']},
#  {'band_singer': ['Aerosmith'],
#   'ranking': '94',
#   'song': ['"Livin\' on the Edge"'],
#   'songurl': ['/wiki/Livin%27_on_the_Edge'],
#   'titletext': ["Livin' on the Edge"],
#   'url': ['/wiki/Aerosmith']},
#  {'band_singer': ['Gin Blossoms'],
#   'ranking': '95',
#   'song': ['"Hey Jealousy"'],
#   'songurl': ['/wiki/Hey_Jealousy'],
#   'titletext': ['Hey Jealousy'],
#   'url': ['/wiki/Gin_Blossoms']},
#  {'band_singer': ['Sting'],
#   'ranking': '96',
#   'song': ['"If I Ever Lose My Faith in You"'],
#   'songurl': ['/wiki/If_I_Ever_Lose_My_Faith_in_You'],
#   'titletext': ['If I Ever Lose My Faith in You'],
#   'url': ['/wiki/Sting_(musician)']},
#  {'band_singer': ['Tony! Toni! Tone!'],
#   'ranking': '97',
#   'song': ['"Anniversary"'],
#   'songurl': ['/wiki/Anniversary'],
#   'titletext': ['Anniversary'],
#   'url': ['/wiki/Tony!_Toni!_Tone!']},
#  {'band_singer': ['Jade'],
#   'ranking': '98',
#   'song': ['"One Woman"'],
#   'songurl': ['/wiki/One_Woman'],
#   'titletext': ['One Woman'],
#   'url': ['/wiki/Jade_(American_band)']},
#  {'band_singer': ['Taylor Dayne'],
#   'ranking': '99',
#   'song': ['"Can\'t Get Enough of Your Love"'],
#   'songurl': ['/wiki/Can%27t_Get_Enough_of_Your_Love'],
#   'titletext': ["Can't Get Enough of Your Love"],
#   'url': ['/wiki/Taylor_Dayne']},
#  {'band_singer': ['Def Leppard'],
#   'ranking': '100',
#   'song': ['"Two Steps Behind"'],
#   'songurl': ['/wiki/Two_Steps_Behind'],
#   'titletext': ['Two Steps Behind'],
#   'url': ['/wiki/Def_Leppard']},
#  {'band_singer': ['Ace of Base'],
#   'ranking': '1',
#   'song': ['"The Sign"'],
#   'songurl': ['/wiki/The_Sign_(song)'],
#   'titletext': ['The Sign (song)'],
#   'url': ['/wiki/Ace_of_Base']},
#  {'band_singer': ['All-4-One'],
#   'ranking': '2',
#   'song': ['"I Swear"'],
#   'songurl': ['/wiki/I_Swear#All-4-One_version'],
#   'titletext': ['I Swear'],
#   'url': ['/wiki/All-4-One']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': '3',
#   'song': ['"I\'ll Make Love to You"'],
#   'songurl': ['/wiki/I%27ll_Make_Love_to_You'],
#   'titletext': ["I'll Make Love to You"],
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Céline Dion'],
#   'ranking': '4',
#   'song': ['"The Power of Love"'],
#   'songurl': ['/wiki/The_Power_of_Love_(Jennifer_Rush_song)#Céline_Dion_version'],
#   'titletext': ['The Power of Love (Jennifer Rush song)'],
#   'url': ['/wiki/C%C3%A9line_Dion']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '5',
#   'song': ['"Hero"'],
#   'songurl': ['/wiki/Hero_(Mariah_Carey_song)'],
#   'titletext': ['Hero (Mariah Carey song)'],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['Lisa Loeb and Nine Stories'],
#   'ranking': '6',
#   'song': ['"Stay (I Missed You)"'],
#   'songurl': ['/wiki/Stay_(I_Missed_You)'],
#   'titletext': ['Stay (I Missed You)'],
#   'url': ['/wiki/Lisa_Loeb']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': '7',
#   'song': ['"Breathe Again"'],
#   'songurl': ['/wiki/Breathe_Again'],
#   'titletext': ['Breathe Again'],
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Bryan Adams, Rod Stewart and Sting'],
#   'ranking': '8',
#   'song': ['"All for Love"'],
#   'songurl': ['/wiki/All_for_Love_(song)'],
#   'titletext': ['All for Love (song)'],
#   'url': ['/wiki/Bryan_Adams', '/wiki/Rod_Stewart', '/wiki/Sting_(musician)']},
#  {'band_singer': ['Ace of Base'],
#   'ranking': '9',
#   'song': ['"All That She Wants"'],
#   'songurl': ['/wiki/All_That_She_Wants'],
#   'titletext': ['All That She Wants'],
#   'url': ['/wiki/Ace_of_Base']},
#  {'band_singer': ['Ace of Base'],
#   'ranking': '10',
#   'song': ['"Don\'t Turn Around"'],
#   'songurl': ['/wiki/Don%27t_Turn_Around'],
#   'titletext': ["Don't Turn Around"],
#   'url': ['/wiki/Ace_of_Base']},
#  {'band_singer': ['R. Kelly'],
#   'ranking': '11',
#   'song': ['"Bump n\' Grind"'],
#   'songurl': ['/wiki/Bump_n%27_Grind_(R._Kelly_song)'],
#   'titletext': ["Bump n' Grind (R. Kelly song)"],
#   'url': ['/wiki/R._Kelly']},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '12',
#   'song': ['"Again"'],
#   'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#   'titletext': ['Again (Janet Jackson song)'],
#   'url': ['/wiki/Janet_Jackson']},
#  {'band_singer': ['Madonna'],
#   'ranking': '13',
#   'song': ['"I\'ll Remember"'],
#   'songurl': ['/wiki/I%27ll_Remember'],
#   'titletext': ["I'll Remember"],
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Salt-n-Pepa and En Vogue'],
#   'ranking': '14',
#   'song': ['"Whatta Man"'],
#   'songurl': ['/wiki/Whatta_Man'],
#   'titletext': ['Whatta Man'],
#   'url': ['/wiki/Salt-n-Pepa', '/wiki/En_Vogue']},
#  {'band_singer': ['John Mellencamp ', ' Meshell Ndegeocello'],
#   'ranking': '15',
#   'song': ['"Wild Night"'],
#   'songurl': ['/wiki/Wild_Night'],
#   'titletext': ['Wild Night'],
#   'url': ['/wiki/John_Mellencamp', '/wiki/Meshell_Ndegeocello']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': '16',
#   'song': ['"Without You" ', ' "Never Forget You"'],
#   'songurl': ['/wiki/Without_You_(Badfinger_song)#Mariah_Carey_version',
#    '/wiki/Never_Forget_You_(Mariah_Carey_song)'],
#   'titletext': ['Without You (Badfinger song)',
#    'Never Forget You (Mariah Carey song)'],
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': '17',
#   'song': ['"You Mean the World to Me"'],
#   'songurl': ['/wiki/You_Mean_the_World_to_Me'],
#   'titletext': ['You Mean the World to Me'],
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Elton John'],
#   'ranking': '18',
#   'song': ['"Can You Feel the Love Tonight"'],
#   'songurl': ['/wiki/Can_You_Feel_the_Love_Tonight'],
#   'titletext': ['Can You Feel the Love Tonight'],
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Prince'],
#   'ranking': '19',
#   'song': ['"The Most Beautiful Girl in the World"'],
#   'songurl': ['/wiki/The_Most_Beautiful_Girl_in_the_World_(Prince_song)'],
#   'titletext': ['The Most Beautiful Girl in the World (Prince song)'],
#   'url': ['/wiki/Prince_(musician)']},
#  {'band_singer': ['Coolio'],
#   'ranking': '20',
#   'song': ['"Fantastic Voyage"'],
#   'songurl': ['/wiki/Fantastic_Voyage_(Coolio_song)'],
#   'titletext': ['Fantastic Voyage (Coolio song)'],
#   'url': ['/wiki/Coolio']},
#  {'band_singer': ['Big Mountain'],
#   'ranking': '21',
#   'song': ['"Baby, I Love Your Way"'],
#   'songurl': ['/wiki/Baby,_I_Love_Your_Way'],
#   'titletext': ['Baby, I Love Your Way'],
#   'url': ['/wiki/Big_Mountain_(band)']},
#  {'band_singer': ['Warren G ', ' Nate Dogg'],
#   'ranking': '22',
#   'song': ['"Regulate"'],
#   'songurl': ['/wiki/Regulate_(song)'],
#   'titletext': ['Regulate (song)'],
#   'url': ['/wiki/Warren_G', '/wiki/Nate_Dogg']},
#  {'band_singer': ['Jon Secada'],
#   'ranking': '23',
#   'song': ['"If You Go"'],
#   'songurl': ['/wiki/If_You_Go_(song)'],
#   'titletext': ['If You Go (song)'],
#   'url': ['/wiki/Jon_Secada']},
#  {'band_singer': ['Aaliyah'],
#   'ranking': '24',
#   'song': ['"Back & Forth"'],
# ...
#   'songurl': ['/wiki/Love_Don%27t_Cost_a_Thing_(song)'],
#   'titletext': ["Love Don't Cost a Thing (song)"],
#   'url': ['/wiki/Jennifer_Lopez']},
#  {'band_singer': ['Faith Hill'],
#   'ranking': '27',
#   'song': ['"The Way You Love Me"'],
#   'songurl': ['/wiki/The_Way_You_Love_Me_(Faith_Hill_song)'],
#   'titletext': ['The Way You Love Me (Faith Hill song)'],
#   'url': ['/wiki/Faith_Hill']},
#  {'band_singer': ['Dream'],
#   'ranking': '28',
#   'song': ['"He Loves U Not"'],
#   'songurl': ['/wiki/He_Loves_U_Not'],
#   'titletext': ['He Loves U Not'],
#   'url': ['/wiki/Dream_(American_group)']},
#  {'band_singer': ['Crazy Town'],
#   'ranking': '29',
#   'song': ['"Butterfly"'],
#   'songurl': ['/wiki/Butterfly_(Crazy_Town_song)'],
#   'titletext': ['Butterfly (Crazy Town song)'],
#   'url': ['/wiki/Crazy_Town']},
#  {'band_singer': ['Ja Rule ', " Lil' Mo and Vita"],
#   'ranking': '30',
#   'song': ['"Put It on Me"'],
#   'songurl': ['/wiki/Put_It_on_Me_(Ja_Rule_song)'],
#   'titletext': ['Put It on Me (Ja Rule song)'],
#   'url': ['/wiki/Ja_Rule', '/wiki/Lil%27_Mo']},
#  {'band_singer': ['Mary J. Blige'],
#   'ranking': '31',
#   'song': ['"Family Affair"'],
#   'songurl': ['/wiki/Family_Affair_(Mary_J._Blige_song)'],
#   'titletext': ['Family Affair (Mary J. Blige song)'],
#   'url': ['/wiki/Mary_J._Blige']},
#  {'band_singer': ['Lee Ann Womack'],
#   'ranking': '32',
#   'song': ['"I Hope You Dance"'],
#   'songurl': ['/wiki/I_Hope_You_Dance_(song)'],
#   'titletext': ['I Hope You Dance (song)'],
#   'url': ['/wiki/Lee_Ann_Womack']},
#  {'band_singer': ['Moby ', ' Gwen Stefani'],
#   'ranking': '33',
#   'song': ['"South Side"'],
#   'songurl': ['/wiki/South_Side_(song)'],
#   'titletext': ['South Side (song)'],
#   'url': ['/wiki/Moby', '/wiki/Gwen_Stefani']},
#  {'band_singer': ['Madonna'],
#   'ranking': '34',
#   'song': ['"Don\'t Tell Me"'],
#   'songurl': ['/wiki/Don%27t_Tell_Me_(Madonna_song)'],
#   'titletext': ["Don't Tell Me (Madonna song)"],
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Missy Elliott'],
#   'ranking': '35',
#   'song': ['"Get Ur Freak On"'],
#   'songurl': ['/wiki/Get_Ur_Freak_On'],
#   'titletext': ['Get Ur Freak On'],
#   'url': ['/wiki/Missy_Elliott']},
#  {'band_singer': ['K-Ci & JoJo'],
#   'ranking': '36',
#   'song': ['"Crazy"'],
#   'songurl': ['/wiki/Crazy_(K-Ci_and_JoJo_song)'],
#   'titletext': ['Crazy (K-Ci and JoJo song)'],
#   'url': ['/wiki/K-Ci_%26_JoJo']},
#  {'band_singer': ['Craig David'],
#   'ranking': '37',
#   'song': ['"Fill Me In"'],
#   'songurl': ['/wiki/Fill_Me_In'],
#   'titletext': ['Fill Me In'],
#   'url': ['/wiki/Craig_David']},
#  {'band_singer': ['Janet Jackson'],
#   'ranking': '38',
#   'song': ['"Someone to Call My Lover"'],
#   'songurl': ['/wiki/Someone_to_Call_My_Lover'],
#   'titletext': ['Someone to Call My Lover'],
#   'url': ['/wiki/Janet_Jackson']},
#  {'band_singer': ['Creed'],
#   'ranking': '39',
#   'song': ['"With Arms Wide Open"'],
#   'songurl': ['/wiki/With_Arms_Wide_Open'],
#   'titletext': ['With Arms Wide Open'],
#   'url': ['/wiki/Creed_(band)']},
#  {'band_singer': ['Mýa'],
#   'ranking': '40',
#   'song': ['"Case of the Ex"'],
#   'songurl': ['/wiki/Case_of_the_Ex'],
#   'titletext': ['Case of the Ex'],
#   'url': ['/wiki/M%C3%BDa']},
#  {'band_singer': ['O-Town'],
#   'ranking': '41',
#   'song': ['"All or Nothing"'],
#   'songurl': ['/wiki/All_or_Nothing_(O-Town_song)'],
#   'titletext': ['All or Nothing (O-Town song)'],
#   'url': ['/wiki/O-Town']},
#  {'band_singer': ["Destiny's Child"],
#   'ranking': '42',
#   'song': ['"Bootylicious"'],
#   'songurl': ['/wiki/Bootylicious'],
#   'titletext': ['Bootylicious'],
#   'url': ['/wiki/Destiny%27s_Child']},
#  {'band_singer': ['Nelly Furtado'],
#   'ranking': '43',
#   'song': ['"I\'m Like a Bird"'],
#   'songurl': ['/wiki/I%27m_Like_a_Bird'],
#   'titletext': ["I'm Like a Bird"],
#   'url': ['/wiki/Nelly_Furtado']},
#  {'band_singer': ['3 Doors Down'],
#   'ranking': '44',
#   'song': ['"Kryptonite"'],
#   'songurl': ['/wiki/Kryptonite_(3_Doors_Down_song)'],
#   'titletext': ['Kryptonite (3 Doors Down song)'],
#   'url': ['/wiki/3_Doors_Down']},
#  {'band_singer': ['R. Kelly ', ' Jay-Z'],
#   'ranking': '45',
#   'song': ['"Fiesta"'],
#   'songurl': ['/wiki/Fiesta_(R._Kelly_song)'],
#   'titletext': ['Fiesta (R. Kelly song)'],
#   'url': ['/wiki/R._Kelly', '/wiki/Jay-Z']},
#  {'band_singer': ['Sugar Ray'],
#   'ranking': '46',
#   'song': ['"When It\'s Over"'],
#   'songurl': ['/wiki/When_It%27s_Over_(Sugar_Ray_song)'],
#   'titletext': ["When It's Over (Sugar Ray song)"],
#   'url': ['/wiki/Sugar_Ray']},
#  {'band_singer': ['Aerosmith'],
#   'ranking': '47',
#   'song': ['"Jaded"'],
#   'songurl': ['/wiki/Jaded_(Aerosmith_song)'],
#   'titletext': ['Jaded (Aerosmith song)'],
#   'url': ['/wiki/Aerosmith']},
#  {'band_singer': ['Jagged Edge'],
#   'ranking': '48',
#   'song': ['"Promise"'],
#   'songurl': ['/wiki/Promise_(Jagged_Edge_song)'],
#   'titletext': ['Promise (Jagged Edge song)'],
#   'url': ['/wiki/Jagged_Edge_(band)']},
#  {'band_singer': ['Case'],
#   'ranking': '49',
#   'song': ['"Missing You"'],
#   'songurl': ['/wiki/Missing_You_(Case_song)'],
#   'titletext': ['Missing You (Case song)'],
#   'url': ['/wiki/Case_(singer)']},
#  {'band_singer': ['Ginuwine'],
#   'ranking': '50',
#   'song': ['"Differences"'],
#   'songurl': ['/wiki/Differences_(song)'],
#   'titletext': ['Differences (song)'],
#   'url': ['/wiki/Ginuwine']},
#  {'band_singer': ["'N Sync"],
#   'ranking': '51',
#   'song': ['"This I Promise You"'],
#   'songurl': ['/wiki/This_I_Promise_You'],
#   'titletext': ['This I Promise You'],
#   'url': ['/wiki/%27N_Sync']},
#  {'band_singer': ['Jay-Z'],
#   'ranking': '52',
#   'song': ['"Izzo (H.O.V.A.)"'],
#   'songurl': ['/wiki/Izzo_(H.O.V.A.)'],
#   'titletext': ['Izzo (H.O.V.A.)'],
#   'url': ['/wiki/Jay-Z']},
#  {'band_singer': ["Lil' Mo ", ' Fabolous'],
#   'ranking': '53',
#   'song': ['"Superwoman Pt. II"'],
#   'songurl': ['/wiki/Superwoman_Pt._II'],
#   'titletext': ['Superwoman Pt. II'],
#   'url': ['/wiki/Lil%27_Mo', '/wiki/Fabolous']},
#  {'band_singer': ['Evan and Jaron'],
#   'ranking': '54',
#   'song': ['"Crazy for This Girl"'],
#   'songurl': ['/wiki/Crazy_for_This_Girl'],
#   'titletext': ['Crazy for This Girl'],
#   'url': ['/wiki/Evan_and_Jaron']},
#  {'band_singer': ['Ricky Martin and Christina Aguilera'],
#   'ranking': '55',
#   'song': ['"Nobody Wants to Be Lonely"'],
#   'songurl': ['/wiki/Nobody_Wants_to_Be_Lonely'],
#   'titletext': ['Nobody Wants to Be Lonely'],
#   'url': ['/wiki/Ricky_Martin', '/wiki/Christina_Aguilera']},
#  {'band_singer': ['Jay-Z'],
#   'ranking': '56',
#   'song': ['"I Just Wanna Love U (Give It 2 Me)"'],
#   'songurl': ['/wiki/I_Just_Wanna_Love_U_(Give_It_2_Me)'],
#   'titletext': ['I Just Wanna Love U (Give It 2 Me)'],
#   'url': ['/wiki/Jay-Z']},
#  {'band_singer': ['Missy Elliott ', ' Ludacris'],
#   'ranking': '57',
#   'song': ['"One Minute Man"'],
#   'songurl': ['/wiki/One_Minute_Man'],
#   'titletext': ['One Minute Man'],
#   'url': ['/wiki/Missy_Elliott', '/wiki/Ludacris']},
#  {'band_singer': ['Mystikal ', ' Nivea'],
#   'ranking': '58',
#   'song': ['"Danger (Been So Long)"'],
#   'songurl': ['/wiki/Danger_(Been_So_Long)'],
#   'titletext': ['Danger (Been So Long)'],
#   'url': ['/wiki/Mystikal', '/wiki/Nivea_(singer)']},
#  {'band_singer': ['Enya'],
#   'ranking': '59',
#   'song': ['"Only Time"'],
#   'songurl': ['/wiki/Only_Time'],
#   'titletext': ['Only Time'],
#   'url': ['/wiki/Enya']},
#  {'band_singer': ['Toya'],
#   'ranking': '60',
#   'song': ['"I Do!!"'],
#   'songurl': ['/wiki/I_Do!!'],
#   'titletext': ['I Do!!'],
#   'url': ['/wiki/Toya_(singer)']},
#  {'band_singer': ['S Club 7'],
#   'ranking': '61',
#   'song': ['"Never Had a Dream Come True"'],
#   'songurl': ['/wiki/Never_Had_a_Dream_Come_True'],
#   'titletext': ['Never Had a Dream Come True'],
#   'url': ['/wiki/S_Club_7']},
#  {'band_singer': ['Tamia'],
#   'ranking': '62',
#   'song': ['"Stranger in My House"'],
#   'songurl': ['/wiki/Stranger_in_My_House_(Tamia_song)'],
#   'titletext': ['Stranger in My House (Tamia song)'],
#   'url': ['/wiki/Tamia']},
#  {'band_singer': ['Jessica Simpson'],
#   'ranking': '63',
#   'song': ['"Irresistible"'],
#   'songurl': ['/wiki/Irresistible_(Jessica_Simpson_song)'],
#   'titletext': ['Irresistible (Jessica Simpson song)'],
#   'url': ['/wiki/Jessica_Simpson']},
#  {'band_singer': ['Sunshine Anderson'],
#   'ranking': '64',
#   'song': ['"Heard It All Before"'],
#   'songurl': ['/wiki/Heard_It_All_Before_(song)'],
#   'titletext': ['Heard It All Before (song)'],
#   'url': ['/wiki/Sunshine_Anderson']},
#  {'band_singer': ['Dave Matthews Band'],
#   'ranking': '65',
#   'song': ['"The Space Between"'],
#   'songurl': ['/wiki/The_Space_Between'],
#   'titletext': ['The Space Between'],
#   'url': ['/wiki/Dave_Matthews_Band']},
#  {'band_singer': ['Faith Hill'],
#   'ranking': '66',
#   'song': ['"There You\'ll Be"'],
#   'songurl': ['/wiki/There_You%27ll_Be'],
#   'titletext': ["There You'll Be"],
#   'url': ['/wiki/Faith_Hill']},
#  {'band_singer': ['Musiq Soulchild'],
#   'ranking': '67',
#   'song': ['"Love"'],
#   'songurl': ['/wiki/Love_(Musiq_Soulchild_song)'],
#   'titletext': ['Love (Musiq Soulchild song)'],
#   'url': ['/wiki/Musiq_Soulchild']},
#  {'band_singer': ['112'],
#   'ranking': '68',
#   'song': ['"It\'s Over Now"'],
#   'songurl': ['/wiki/It%27s_Over_Now_(112_song)'],
#   'titletext': ["It's Over Now (112 song)"],
#   'url': ['/wiki/112_(band)']},
#  {'band_singer': ['3LW'],
#   'ranking': '69',
#   'song': ['"No More (Baby I\'ma Do Right)"'],
#   'songurl': ['/wiki/No_More_(Baby_I%27ma_Do_Right)'],
#   'titletext': ["No More (Baby I'ma Do Right)"],
#   'url': ['/wiki/3LW']},
#  {'band_singer': ['Nelly Furtado'],
#   'ranking': '70',
#   'song': ['"Turn Off the Light"'],
#   'songurl': ['/wiki/Turn_Off_the_Light'],
#   'titletext': ['Turn Off the Light'],
#   'url': ['/wiki/Nelly_Furtado']},
#  {'band_singer': ['Brooks & Dunn'],
#   'ranking': '71',
#   'song': ['"Ain\'t Nothing \'bout You"'],
#   'songurl': ['/wiki/Ain%27t_Nothing_%27bout_You'],
#   'titletext': ["Ain't Nothing 'bout You"],
#   'url': ['/wiki/Brooks_%26_Dunn']},
#  {'band_singer': ['Jennifer Lopez'],
#   'ranking': '72',
#   'song': ['"Play"'],
#   'songurl': ['/wiki/Play_(Jennifer_Lopez_song)'],
#   'titletext': ['Play (Jennifer Lopez song)'],
#   'url': ['/wiki/Jennifer_Lopez']},
#  {'band_singer': ['Lonestar'],
#   'ranking': '73',
#   'song': ['"I\'m Already There"'],
#   'songurl': ['/wiki/I%27m_Already_There_(song)'],
#   'titletext': ["I'm Already There (song)"],
#   'url': ['/wiki/Lonestar']},
#  {'band_singer': ["Lil' Romeo"],
#   'ranking': '74',
#   'song': ['"My Baby"'],
#   'songurl': ['/wiki/My_Baby_(Lil%27_Romeo_song)'],
#   'titletext': ["My Baby (Lil' Romeo song)"],
#   'url': ['/wiki/Romeo_Miller']},
#  {'band_singer': ['U2'],
#   'ranking': '75',
#   'song': ['"Beautiful Day"'],
#   'songurl': ['/wiki/Beautiful_Day'],
#   'titletext': ['Beautiful Day'],
#   'url': ['/wiki/U2']},
#  {'band_singer': ['Blake Shelton'],
#   'ranking': '76',
#   'song': ['"Austin"'],
#   'songurl': ['/wiki/Austin_(song)'],
#   'titletext': ['Austin (song)'],
#   'url': ['/wiki/Blake_Shelton']},
#  {'band_singer': ['Ludacris'],
#   'ranking': '77',
#   'song': ['"Southern Hospitality"'],
#   'songurl': ['/wiki/Southern_Hospitality_(song)'],
#   'titletext': ['Southern Hospitality (song)'],
#   'url': ['/wiki/Ludacris']},
#  {'band_singer': ['Tim McGraw'],
#   'ranking': '78',
#   'song': ['"Grown Men Don\'t Cry"'],
#   'songurl': ['/wiki/Grown_Men_Don%27t_Cry'],
#   'titletext': ["Grown Men Don't Cry"],
#   'url': ['/wiki/Tim_McGraw']},
#  {'band_singer': ['Ja Rule ', ' Case'],
#   'ranking': '79',
#   'song': ['"Livin\' It Up"'],
#   'songurl': ['/wiki/Livin%27_It_Up_(Ja_Rule_song)'],
#   'titletext': ["Livin' It Up (Ja Rule song)"],
#   'url': ['/wiki/Ja_Rule', '/wiki/Case_(singer)']},
#  {'band_singer': ['Mariah Carey ', ' Cameo'],
#   'ranking': '80',
#   'song': ['"Loverboy"'],
#   'songurl': ['/wiki/Loverboy_(Mariah_Carey_song)'],
#   'titletext': ['Loverboy (Mariah Carey song)'],
#   'url': ['/wiki/Mariah_Carey', '/wiki/Cameo_(band)']},
#  {'band_singer': ['The Isley Brothers ', ' R. Kelly and Chanté Moore'],
#   'ranking': '81',
#   'song': ['"Contagious"'],
#   'songurl': ['/wiki/Contagious_(song)'],
#   'titletext': ['Contagious (song)'],
#   'url': ['/wiki/The_Isley_Brothers',
#    '/wiki/R._Kelly',
#    '/wiki/Chant%C3%A9_Moore']},
#  {'band_singer': ['Jessica Andrews'],
#   'ranking': '82',
#   'song': ['"Who I Am"'],
#   'songurl': ['/wiki/Who_I_Am_(Jessica_Andrews_song)'],
#   'titletext': ['Who I Am (Jessica Andrews song)'],
#   'url': ['/wiki/Jessica_Andrews']},
#  {'band_singer': ['Erick Sermon ', ' Marvin Gaye'],
#   'ranking': '83',
#   'song': ['"Music"'],
#   'songurl': ['/wiki/Music_(Erick_Sermon_and_Marvin_Gaye_song)'],
#   'titletext': ['Music (Erick Sermon and Marvin Gaye song)'],
#   'url': ['/wiki/Erick_Sermon', '/wiki/Marvin_Gaye']},
#  {'band_singer': ['Willa Ford'],
#   'ranking': '84',
#   'song': ['"I Wanna Be Bad"'],
#   'songurl': ['/wiki/I_Wanna_Be_Bad'],
#   'titletext': ['I Wanna Be Bad'],
#   'url': ['/wiki/Willa_Ford']},
#  {'band_singer': ['Kenny Chesney'],
#   'ranking': '85',
#   'song': ['"Don\'t Happen Twice"'],
#   'songurl': ['/wiki/Don%27t_Happen_Twice'],
#   'titletext': ["Don't Happen Twice"],
#   'url': ['/wiki/Kenny_Chesney']},
#  {'band_singer': ['Diamond Rio'],
#   'ranking': '86',
#   'song': ['"One More Day"'],
#   'songurl': ['/wiki/One_More_Day_(Diamond_Rio_song)'],
#   'titletext': ['One More Day (Diamond Rio song)'],
#   'url': ['/wiki/Diamond_Rio']},
#  {'band_singer': ['R. Kelly'],
#   'ranking': '87',
#   'song': ['"I Wish"'],
#   'songurl': ['/wiki/I_Wish_(R._Kelly_song)'],
#   'titletext': ['I Wish (R. Kelly song)'],
#   'url': ['/wiki/R._Kelly']},
#  {'band_singer': ['Travis Tritt'],
#   'ranking': '88',
#   'song': ['"It\'s a Great Day to Be Alive"'],
#   'songurl': ['/wiki/It%27s_a_Great_Day_to_Be_Alive'],
#   'titletext': ["It's a Great Day to Be Alive"],
#   'url': ['/wiki/Travis_Tritt']},
#  {'band_singer': ['Trick Daddy'],
#   'ranking': '89',
#   'song': ['"I\'m a Thug"'],
#   'songurl': ['/wiki/Trick_Daddy'],
#   'titletext': ['Trick Daddy'],
#   'url': None},
#  {'band_singer': ['Eve 6'],
#   'ranking': '90',
#   'song': ['"Here\'s to the Night"'],
#   'songurl': ['/wiki/Here%27s_to_the_Night'],
#   'titletext': ["Here's to the Night"],
#   'url': ['/wiki/Eve_6']},
#  {'band_singer': ['Toby Keith'],
#   'ranking': '91',
#   'song': ['"You Shouldn\'t Kiss Me Like This"'],
#   'songurl': ['/wiki/You_Shouldn%27t_Kiss_Me_Like_This'],
#   'titletext': ["You Shouldn't Kiss Me Like This"],
#   'url': ['/wiki/Toby_Keith']},
#  {'band_singer': ["Eden's Crush"],
#   'ranking': '92',
#   'song': ['"Get Over Yourself"'],
#   'songurl': ['/wiki/Get_Over_Yourself_(song)'],
#   'titletext': ['Get Over Yourself (song)'],
#   'url': ['/wiki/Eden%27s_Crush']},
#  {'band_singer': ['Debelah Morgan'],
#   'ranking': '93',
#   'song': ['"Dance with Me"'],
#   'songurl': ['/wiki/Dance_with_Me_(Debelah_Morgan_song)'],
#   'titletext': ['Dance with Me (Debelah Morgan song)'],
#   'url': ['/wiki/Debelah_Morgan']},
#  {'band_singer': ['Outkast'],
#   'ranking': '94',
#   'song': ['"So Fresh So Clean"'],
#   'songurl': ['/wiki/So_Fresh_So_Clean'],
#   'titletext': ['So Fresh So Clean'],
#   'url': ['/wiki/Outkast']},
#  {'band_singer': ['Nelly'],
#   'ranking': '95',
#   'song': ['"E.I."'],
#   'songurl': ['/wiki/E.I._(song)'],
#   'titletext': ['E.I. (song)'],
#   'url': ['/wiki/Nelly']},
#  {'band_singer': ['3 Doors Down'],
#   'ranking': '96',
#   'song': ['"Be Like That"'],
#   'songurl': ['/wiki/Be_Like_That'],
#   'titletext': ['Be Like That'],
#   'url': ['/wiki/3_Doors_Down']},
#  {'band_singer': ['Pink'],
#   'ranking': '97',
#   'song': ['"Most Girls"'],
#   'songurl': ['/wiki/Most_Girls_(Pink_song)'],
#   'titletext': ['Most Girls (Pink song)'],
#   'url': ['/wiki/Pink_(singer)']},
#  {'band_singer': ['Nas and Bravehearts'],
#   'ranking': '98',
#   'song': ['"Oochie Wally"'],
#   'songurl': ['/wiki/Oochie_Wally'],
#   'titletext': ['Oochie Wally'],
#   'url': ['/wiki/Nas', '/wiki/Bravehearts']},
#  {'band_singer': ['Enrique Iglesias'],
#   'ranking': '99',
#   'song': ['"Hero"'],
#   'songurl': ['/wiki/Hero_(Enrique_Iglesias_song)'],
#   'titletext': ['Hero (Enrique Iglesias song)'],
#   'url': ['/wiki/Enrique_Iglesias']},
#  {'band_singer': ['Fuel'],
#   'ranking': '100',
#   'song': ['"Hemorrhage (In My Hands)"'],
#   'songurl': ['/wiki/Hemorrhage_(In_My_Hands)'],
#   'titletext': ['Hemorrhage (In My Hands)'],
#   'url': ['/wiki/Fuel_(band)']},
#  ...]

# %%
years = []
dicts = []
lists = [lis for lis in dicts_lis]
for i,year in enumerate(range(1992,2014)):
    dicts = dicts + lists[i]
    years = years + list(np.ones(100,dtype=int)*year)
singer_df = pd.DataFrame(dicts)
singer_df.insert(0,'year',years)

singer_df.head(10)
# Out:
#    year              band_singer ranking                                       song                                            songurl                                titletext                            url
# 0  1992            [Boyz II Men]       1                        ["End of the Road"]                            [/wiki/End_of_the_Road]                        [End of the Road]            [/wiki/Boyz_II_Men]
# 1  1992          [Sir Mix-a-Lot]       2                          ["Baby Got Back"]                              [/wiki/Baby_Got_Back]                          [Baby Got Back]          [/wiki/Sir_Mix-a-Lot]
# 2  1992             [Kris Kross]       3                                   ["Jump"]                     [/wiki/Jump_(Kris_Kross_song)]                 [Jump (Kris Kross song)]             [/wiki/Kris_Kross]
# 3  1992       [Vanessa Williams]       4                 ["Save the Best for Last"]                     [/wiki/Save_the_Best_for_Last]                 [Save the Best for Last]    [/wiki/Vanessa_L._Williams]
# 4  1992                    [TLC]       5                         ["Baby-Baby-Baby"]                             [/wiki/Baby-Baby-Baby]                         [Baby-Baby-Baby]             [/wiki/TLC_(band)]
# 5  1992           [Eric Clapton]       6                        ["Tears in Heaven"]                            [/wiki/Tears_in_Heaven]                        [Tears in Heaven]           [/wiki/Eric_Clapton]
# 6  1992               [En Vogue]       7  ["My Lovin' (You're Never Gonna Get It)"]  [/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)]  [My Lovin' (You're Never Gonna Get It)]               [/wiki/En_Vogue]
# 7  1992  [Red Hot Chili Peppers]       8                       ["Under the Bridge"]                           [/wiki/Under_the_Bridge]                       [Under the Bridge]  [/wiki/Red_Hot_Chili_Peppers]
# 8  1992          [Color Me Badd]       9                             ["All 4 Love"]                                 [/wiki/All_4_Love]                             [All 4 Love]          [/wiki/Color_Me_Badd]
# 9  1992             [Jon Secada]      10                       ["Just Another Day"]         [/wiki/Just_Another_Day_(Jon_Secada_song)]     [Just Another Day (Jon Secada song)]             [/wiki/Jon_Secada]

# %%
for col in ['band_singer','songurl','titletext','url','song']:
    singer_df[col] = singer_df[col].apply(lambda s: str(s).strip("[']"))
#df.band_singer = df.band_singer.apply(lambda s: str(s).strip("['']" ))
#df.songurl = df.songurl.apply(lambda s: str(s).strip("[]" ))

singer_df.titletext = singer_df.titletext.apply(lambda s: s.strip('""'))
singer_df.song = singer_df.song.apply(lambda s: s.strip('""'))
singer_df.sort_values(['ranking','year'],inplace=True)
singer_df.reset_index(inplace=True)
del singer_df['titletext']
singer_df.head(10)
# Out:
#    index  year       band_singer ranking                                               song                                            songurl                                  url
# 0      0  1992       Boyz II Men       1                                    End of the Road                              /wiki/End_of_the_Road                    /wiki/Boyz_II_Men
# 1    100  1993   Whitney Houston       1                             I Will Always Love You  /wiki/I_Will_Always_Love_You#Whitney_Houston_v...                /wiki/Whitney_Houston
# 2    200  1994       Ace of Base       1                                           The Sign                              /wiki/The_Sign_(song)                    /wiki/Ace_of_Base
# 3    300  1995  Coolio ', ' L.V.       1                                Gangsta\'s Paradise                         /wiki/Gangsta%27s_Paradise  /wiki/Coolio', '/wiki/L.V._(singer)
# 4    400  1996       Los del Río       1                        Macarena (Bayside Boys Mix)                              /wiki/Macarena_(song)               /wiki/Los_del_R%C3%ADo
# 5    500  1997        Elton John       1  Something About the Way You Look Tonight" ', '...  /wiki/Something_About_the_Way_You_Look_Tonight...                     /wiki/Elton_John
# 6    600  1998              Next       1                                          Too Close                        /wiki/Too_Close_(Next_song)                   /wiki/Next_(group)
# 7    700  1999              Cher       1                                            Believe                          /wiki/Believe_(Cher_song)                           /wiki/Cher
# 8    800  2000        Faith Hill       1                                            Breathe                    /wiki/Breathe_(Faith_Hill_song)                     /wiki/Faith_Hill
# 9    900  2001         Lifehouse       1                                Hanging by a Moment                          /wiki/Hanging_by_a_Moment               /wiki/Lifehouse_(band)

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %%
singer_df.ranking = singer_df.ranking.astype(int)

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
count_singers = singer_df.url.value_counts() 
top_singers = count_singers[count_singers>=15]

plt.bar(range(len(top_singers)),top_singers.values,alpha=0.6)

plt.xticks(range(len(top_singers)),top_singers.keys(),rotation='vertical')
plt.ylabel('Prolific [frequency]')
plt.xlabel('Singer')
plt.show()

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
def get_score(pos):
    if pos <= 80:
        score = 5
    elif 80 < pos <= 60:
        score = 4
    elif 60 < pos <= 40:
        score = 3
    elif 40 < pos <= 20:
        score = 2
    else:
        score = 1
    return score    
def calc_total_score(rankings):
    total_score = 0
    for rank in rankings:
        total_score += get_score(rank) 
    return total_score

# %%
scores = {}
singers = singer_df.band_singer.unique()
for singer in singers:
    ranks = singer_df.loc[(singer_df.band_singer == singer),'ranking']
    scores[singer] = calc_total_score(ranks)

# %%
sorted_singers = sorted(scores,key=scores.get,reverse=True)
top_singers = sorted_singers[:7]

top_scores = [scores[singer] for singer in top_singers]
plt.bar(range(len(top_singers)),top_scores,alpha=0.6)

plt.xticks(range(len(top_singers)),top_singers,rotation='vertical')
plt.ylabel('101 Score')
plt.xlabel('Singer')
plt.show()

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %% [markdown]
# #### Pulling and saving the data

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
#flatframe["url"].apply(get_page)
df['url'].apply(get_page)
# Out:
# 0       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 1       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3                                                       1
# 4       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 5       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 6       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 7       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 8       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 9       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 10      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 11      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 12                                                      1
# 13      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 14      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 15      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 16                                                      1
# 17      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 18      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 19      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 20                                                      1
# 21                                                      1
# 22      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 23      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 24      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 25      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 26      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 27      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 28      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 29      <!DOCTYPE html>\n<html class="client-nojs" lan...
#                               ...
# 2170    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2171    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2172                                                    1
# 2173                                                    1
# 2174    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2175                                                    1
# 2176    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2177    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2178    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2179    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2180                                                    1
# 2181    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2182    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2183    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2184    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2185                                                    1
# 2186    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2187    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2188    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2189    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2190    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2191    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2192    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2193                                                    1
# 2194    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2195    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2196    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2197    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2198    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2199    <!DOCTYPE html>\n<html class="client-nojs" lan...
# Name: url, Length: 2200, dtype: object

# %%
type(urlcache)
# Out:
# dict

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(singer_df.url.unique())==len(urlcache)) # we got all of the urls
# Out:
# Number of bad requests: 464
# Did we get all urls? True

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""
def singer_band_info(url,page_text):
    singer_band_dict = {'url':url, 'born':False,'ya':False}    
    soup = BeautifulSoup(page_text,'html.parser')        
    ths = soup.find_all('th')                    
    for th in ths:
        if th.text == 'Born':
            singer_band_dict['born'] = th.find_next('td').text
        elif th.text == 'Years active': 
            singer_band_dict['ya'] = not singer_band_dict['born'] and th.find_next('td').text
    return singer_band_dict

# %% [markdown]
# #### 2.2  Merging this information in

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %%
singer_band_dicts = []
for i,url in enumerate(urlcache):
    page = urlcache[singer_df.url[i]]
    if page!=1 and page!=2:    
        singer_band_dicts.append(singer_band_info(url,page))

# %%
singer_temp = singer_band_dicts.copy()

# %%
for dic in singer_band_dicts:
    s = dic['born']
    if s:    
        r = re.compile('\d{4}[-]\d{2}[-]\d{2}')
        dic['born'] = r.findall(dic['born'])
        print( r.findall(dic['born']))
info_df = pd.DataFrame(singer_band_dicts)
info_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-524-f2262d66c2cb> in <module>()
#       3     if s:
#       4         r = re.compile('\d{4}[-]\d{2}[-]\d{2}')
# ----> 5         dic['born'] = r.findall(dic['born'])
#       6         print( r.findall(dic['born']))
#       7 info_df = pd.DataFrame(singer_band_dicts)
#
# TypeError: expected string or bytes-like object

# %%
info_df.born = info_df.loc[:,'born'].apply(lambda s: str(s).strip("['']"))

# %%
singer_df.sort_values('year',inplace=True)
new_df = pd.merge(singer_df,info_df,on='url',how='inner')

# %%
born_df = new_df[new_df['born']!='False']
born_df
# Out:
#       year                                   band_singer  ranking                                     song                                          songurl                                                url        born     ya
# 12    1992                                  Eric Clapton        6                          Tears in Heaven                            /wiki/Tears_in_Heaven                                 /wiki/Eric_Clapton  1988-02-20  False
# 13    1996                                  Eric Clapton       19                         Change the World                           /wiki/Change_the_World                                 /wiki/Eric_Clapton  1988-02-20  False
# 14    1997                                  Eric Clapton       67                         Change the World                           /wiki/Change_the_World                                 /wiki/Eric_Clapton  1988-02-20  False
# 17    1992                          Arrested Development       40                                Tennessee      /wiki/Tennessee_(Arrested_Development_song)                 /wiki/Arrested_Development_(group)  1981-09-04  False
# 18    1992                          Arrested Development       67                          People Everyday                            /wiki/People_Everyday                 /wiki/Arrested_Development_(group)  1981-09-04  False
# 19    1993                          Arrested Development       31                               Mr. Wendal                                 /wiki/Mr._Wendal                 /wiki/Arrested_Development_(group)  1981-09-04  False
# 20    1992                                   Paula Abdul       73               Blowing Kisses in the Wind                 /wiki/Blowing_Kisses_in_the_Wind                                  /wiki/Paula_Abdul  1989-12-13  False
# 28    1992                              Vanessa Williams        4                   Save the Best for Last                     /wiki/Save_the_Best_for_Last                          /wiki/Vanessa_L._Williams  1988-05-05  False
# 29    1995                              Vanessa Williams       75                        The Sweetest Days  /wiki/The_Sweetest_Days_(Vanessa_Williams_song)                          /wiki/Vanessa_L._Williams  1988-05-05  False
# 30    1995                              Vanessa Williams       31                       Colors of the Wind                         /wiki/Colors_of_the_Wind                          /wiki/Vanessa_L._Williams  1988-05-05  False
# 32    1992                                 CeCe Peniston       20                                  Finally               /wiki/Finally_(CeCe_Peniston_song)                                /wiki/CeCe_Peniston  1968-10-22  False
# 33    1992                                 CeCe Peniston       61                         Keep on Walkin\'                   /wiki/Keep_on_Walkin%27_(song)                                /wiki/CeCe_Peniston  1968-10-22  False
# 34    1992                                 CeCe Peniston       97                      We Got a Love Thang                        /wiki/We_Got_a_Love_Thang                                /wiki/CeCe_Peniston  1968-10-22  False
# 35    1992                                     P.M. Dawn       51                     I\'d Die Without You                      /wiki/I%27d_Die_Without_You                                    /wiki/P.M._Dawn  1966-05-16  False
# 36    1992                                     P.M. Dawn       44               Set Adrift on Memory Bliss                 /wiki/Set_Adrift_on_Memory_Bliss                                    /wiki/P.M._Dawn  1966-05-16  False
# 37    1993                                     P.M. Dawn       38             Looking Through Patient Eyes               /wiki/Looking_Through_Patient_Eyes                                    /wiki/P.M._Dawn  1966-05-16  False
# 38    1993                                     P.M. Dawn       43                     I\'d Die Without You                      /wiki/I%27d_Die_Without_You                                    /wiki/P.M._Dawn  1966-05-16  False
# 39    1992                                      En Vogue       29         Giving Him Something He Can Feel                      /wiki/Something_He_Can_Feel                                     /wiki/En_Vogue  1972-05-21  False
# 40    1992                                      En Vogue        7  My Lovin\' (You\'re Never Gonna Get It)  /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)                                     /wiki/En_Vogue  1972-05-21  False
# 41    1992                                      En Vogue       93                           Free Your Mind                      /wiki/Free_Your_Mind_(song)                                     /wiki/En_Vogue  1972-05-21  False
# 42    1993                                      En Vogue       84                Give It Up, Turn It Loose                  /wiki/Give_It_Up,_Turn_It_Loose                                     /wiki/En_Vogue  1972-05-21  False
# 43    1997                                      En Vogue        7                     Don\'t Let Go (Love)                      /wiki/Don%27t_Let_Go_(Love)                                     /wiki/En_Vogue  1972-05-21  False
# 44    1992                                     Amy Grant       52                              Good for Me                         /wiki/Good_for_Me_(song)                                    /wiki/Amy_Grant  1979-02-11  False
# 45    1992                                     Amy Grant       91                 That\'s What Love Is For                  /wiki/That%27s_What_Love_Is_For                                    /wiki/Amy_Grant  1979-02-11  False
# 46    1992                                     Amy Grant       96                      I Will Remember You       /wiki/I_Will_Remember_You_(Amy_Grant_song)                                    /wiki/Amy_Grant  1979-02-11  False
# 47    1992                                   Bryan Adams       70              Do I Have to Say the Words?              /wiki/Do_I_Have_to_Say_the_Words%3F                                  /wiki/Bryan_Adams  1984-10-25  False
# 48    1992                                   Bryan Adams       74     Thought I\'d Died and Gone to Heaven      /wiki/Thought_I%27d_Died_and_Gone_to_Heaven                                  /wiki/Bryan_Adams  1984-10-25  False
# 49    1994                                   Bryan Adams       27                        Please Forgive Me                          /wiki/Please_Forgive_Me                                  /wiki/Bryan_Adams  1984-10-25  False
# 50    1995                                   Bryan Adams       16      Have You Ever Really Loved a Woman?      /wiki/Have_You_Ever_Really_Loved_a_Woman%3F                                  /wiki/Bryan_Adams  1984-10-25  False
# 55    1992                                   Keith Sweat       94                          Keep It Comin\'                    /wiki/Keep_It_Comin%27_(song)                                  /wiki/Keith_Sweat  1968-12-03  False
# ...    ...                                           ...      ...                                      ...                                              ...                                                ...         ...    ...
# 1594  2012                     Big Sean ', ' Nicki Minaj       57                              Dance (A$$)                                /wiki/Dance_(A$$)                /wiki/Big_Sean', '/wiki/Nicki_Minaj  1968-03-30  False
# 1598  2012                                 Calvin Harris       42                            Feel So Close                              /wiki/Feel_So_Close                                /wiki/Calvin_Harris  1978-12-30  False
# 1601  2012                             Flo Rida ', ' Sia       11                                Wild Ones                           /wiki/Wild_Ones_(song)                 /wiki/Flo_Rida', '/wiki/Sia_Furler  1989-12-13  False
# 1603  2012                                    Alex Clare       30                                Too Close                /wiki/Too_Close_(Alex_Clare_song)                                   /wiki/Alex_Clare  1979-09-08  False
# 1604  2013               Rocko ', ' Future and Rick Ross       87                               U.O.E.N.O.                                 /wiki/U.O.E.N.O.  /wiki/Rocko_(rapper)', '/wiki/Future_(rapper)'...  1971-12-24  False
# 1606  2013  Tim McGraw ', ' Taylor Swift and Keith Urban       77                      Highway Don\'t Care                       /wiki/Highway_Don%27t_Care  /wiki/Tim_McGraw', '/wiki/Taylor_Swift', '/wik...  1985-06-21  False
# 1608  2013                                    Ed Sheeran       75                               The A Team               /wiki/The_A_Team_(Ed_Sheeran_song)                                   /wiki/Ed_Sheeran  1966-05-16  False
# 1609  2013     Macklemore and Ryan Lewis ', ' Ray Dalton        5                           Can\'t Hold Us                            /wiki/Can%27t_Hold_Us  /wiki/Macklemore', '/wiki/Ryan_Lewis', '/wiki/...  1976-11-12  False
# 1610  2013               Lana Del Rey and Cédric Gervais       45                       Summertime Sadness                         /wiki/Summertime_Sadness    /wiki/Lana_Del_Rey', '/wiki/C%C3%A9dric_Gervais  1969-10-17  False
# 1612  2013                           Of Monsters and Men       65                             Little Talks                               /wiki/Little_Talks                          /wiki/Of_Monsters_and_Men  1978-12-02  False
# 1613  2013                                  Thomas Rhett       90                        It Goes Like This                   /wiki/It_Goes_Like_This_(song)                                 /wiki/Thomas_Rhett  1979-09-08  False
# 1614  2013                        Wale ', ' Tiara Thomas       59                                      Bad                            /wiki/Bad_(Wale_song)          /wiki/Wale_(rapper)', '/wiki/Tiara_Thomas  1979-10-10  False
# 1615  2013             Calvin Harris ', ' Ellie Goulding       56                         I Need Your Love      /wiki/I_Need_Your_Love_(Calvin_Harris_song)        /wiki/Calvin_Harris', '/wiki/Ellie_Goulding  1975-09-09  False
# 1616  2013                                 Darius Rucker       54                              Wagon Wheel                         /wiki/Wagon_Wheel_(song)                                /wiki/Darius_Rucker  1979-09-08  False
# 1619  2013          Swedish House Mafia ', ' John Martin       26                   Don\'t You Worry Child                    /wiki/Don%27t_You_Worry_Child  /wiki/Swedish_House_Mafia', '/wiki/John_Martin...  1985-08-09  False
# 1620  2013                               Zedd ', ' Foxes       24                                  Clarity                        /wiki/Clarity_(Zedd_song)      /wiki/Zedd_(musician)', '/wiki/Foxes_(singer)  1979-10-18  False
# 1622  2013                Justin Bieber ', ' Nicki Minaj       42                        Beauty and a Beat                          /wiki/Beauty_and_a_Beat           /wiki/Justin_Bieber', '/wiki/Nicki_Minaj  1973-11-27  False
# 1623  2013   Macklemore and Ryan Lewis ', ' Mary Lambert       43                                Same Love                                  /wiki/Same_Love  /wiki/Macklemore', '/wiki/Ryan_Lewis', '/wiki/...  1953-02-26  False
# 1625  2013               Lil Wayne ', ' Drake and Future       39                                  Love Me                   /wiki/Love_Me_(Lil_Wayne_song)  /wiki/Lil_Wayne', '/wiki/Drake_(entertainer)',...  1968-03-30  False
# 1627  2013               Pitbull ', ' Christina Aguilera       36                         Feel This Moment                           /wiki/Feel_This_Moment  /wiki/Pitbull_(singer)', '/wiki/Christina_Agui...  1962-02-11  False
# 1628  2013                                   Emeli Sandé       88                               Next to Me         /wiki/Next_to_Me_(Emeli_Sand%C3%A9_song)                             /wiki/Emeli_Sand%C3%A9  1979-09-08  False
# 1629  2013                 will.i.am ', ' Britney Spears       23                           Scream & Shout                           /wiki/Scream_%26_Shout            /wiki/Will.i.am', '/wiki/Britney_Spears  1968-01-14  False
# 1630  2013                  Jay Z ', ' Justin Timberlake       22                               Holy Grail                    /wiki/Holy_Grail_(Jay-Z_song)             /wiki/Jay_Z', '/wiki/Justin_Timberlake  1981-01-25  False
# 1631  2013                  Justin Timberlake ', ' Jay-Z       20                               Suit & Tie                               /wiki/Suit_%26_Tie             /wiki/Justin_Timberlake', '/wiki/Jay-Z  1986-03-28  False
# 1632  2013  Robin Thicke ', ' T.I. and Pharrell Williams        2                            Blurred Lines                              /wiki/Blurred_Lines  /wiki/Robin_Thicke', '/wiki/T.I.', '/wiki/Phar...  1947-03-25  False
# 1633  2013                                        Avicii       19                               Wake Me Up                   /wiki/Wake_Me_Up_(Avicii_song)                                       /wiki/Avicii  1958-08-16  False
# 1634  2013                     Icona Pop ', ' Charli XCX       28                                I Love It                 /wiki/I_Love_It_(Icona_Pop_song)                /wiki/Icona_Pop', '/wiki/Charli_XCX  1961-10-04  False
# 1638  2013                                        Baauer        4                             Harlem Shake                        /wiki/Harlem_Shake_(song)                                       /wiki/Baauer  1981-01-25  False
# 1639  2013                  will.i.am ', ' Justin Bieber       95                               #thatPower                                  /wiki/ThatPower             /wiki/Will.i.am', '/wiki/Justin_Bieber  1993-07-28  False
# 1640  2013                                      2 Chainz       99                           I\'m Different            /wiki/I%27m_Different_(2_Chainz_song)                                     /wiki/2_Chainz  1965-08-28  False
#
# [999 rows x 8 columns]

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %%
#born_df['borny'] = born_df.year - born_df['born'].apply(lambda s:s[:4]).astype(str)
valid_df = born_df[born_df['born']!='']
success_age = valid_df['year'] - valid_df['born'].apply(lambda s:s.split('-')[0]).astype(int)
plt.hist(success_age,bins=15)
plt.xlabel('Age of success')
plt.ylabel('Frequency')

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %%
ya_df = new_df.loc[new_df['ya']!=False]
r = re.compile('\d{4}')
diff = [year-int(r.search(ya).group()) for ya,year in zip(ya_df.ya,ya_df.year) if r.search(ya)]

plt.hist(diff)
# Out:
# (array([   4.,   14.,   24.,   99.,  140.,  144.,  135.,   52.,   15.,    9.]),
#  array([-18. , -12.7,  -7.4,  -2.1,   3.2,   8.5,  13.8,  19.1,  24.4,
#          29.7,  35. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?
